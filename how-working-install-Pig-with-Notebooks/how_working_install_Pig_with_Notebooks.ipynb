# %% [markdown]
# <a href="https://colab.research.google.com/github/xlmriosx/data-projects/blob/main/how-working-install-Pig-with-Notebooks/how_working_install_Pig_with_Notebooks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🐷📝 Basic commands to work with Pig in Notebooks
# ---
# ## 🔗Related content
# ### You can find post related in:
# 👨‍💻[DEV](https://dev.to/xlmriosx/how-workinginstall-hadoop-with-notebooks-34lj)
#
# ### You can find video related in:
# 📺[YouTube](https://youtu.be/tiF05Nh-zn8)
#
# ### You can find repo related in:
# 🐱‍🏍[GitHub](https://github.com/xlmriosx/How-working-install-Hadoop-with-Notebooks)
#
# ### You can connect with me in:
# 🧬[LinkedIn](https://www.linkedin.com/in/xlmriosx/)
#
# ---

# %% [markdown]
# ### Resume 🧾
#
# I will install Hadoop with Pig program and will use a library of Python to write a job that answer the question, how many row exists by each rating?
#
# First I install Hadoop using same commands that I have used before but without put a number of step.

# %% [markdown]
# ---
#
# ### Install Hadoop 🐘
#
# I use following command but you can change to get current last version:
#
# `!wget https://downloads.apache.org/hadoop/common/hadoop-3.3.4/hadoop-3.3.4.tar.gz`

# %%
# !wget https://downloads.apache.org/hadoop/common/hadoop-3.3.4/hadoop-3.3.4.tar.gz
# Out:
# --2023-01-26 23:02:03--  https://downloads.apache.org/hadoop/common/hadoop-3.3.4/hadoop-3.3.4.tar.gz
# Resolving downloads.apache.org (downloads.apache.org)... 88.99.95.219, 135.181.214.104, 2a01:4f8:10a:201a::2, ...
# Connecting to downloads.apache.org (downloads.apache.org)|88.99.95.219|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 695457782 (663M) [application/x-gzip]
# Saving to: ‘hadoop-3.3.4.tar.gz’
#
# hadoop-3.3.4.tar.gz 100%[===================>] 663.24M  31.3MB/s    in 22s
#
# 2023-01-26 23:02:25 (30.4 MB/s) - ‘hadoop-3.3.4.tar.gz’ saved [695457782/695457782]

# %% [markdown]
# You would can get other version if you need in: https://downloads.apache.org/hadoop/common/ and later replace it in the before command.

# %% [markdown]
# ---
#
# ### Unzip and copy 🔓
#
# I use following command:
#
# `!tar -xzvf hadoop-3.3.4.tar.gz && cp -r hadoop-3.3.4/ /usr/local/`

# %%
# !tar -xzvf hadoop-3.3.4.tar.gz && cp -r hadoop-3.3.4/ /usr/local/

# %% [markdown]
# ---
#
# ### Set up Hadoop's Java ☕
#
# I use following command:
# ```
# #To find the default Java path and add export in hadoop-env.sh
# JAVA_HOME = !readlink -f /usr/bin/java | sed "s:bin/java::"
# java_home_text = JAVA_HOME[0]
# java_home_text_command = f"$ {JAVA_HOME[0]} "
# !echo export JAVA_HOME=$java_home_text >>/usr/local/hadoop-3.3.4/etc/hadoop/hadoop-env.sh
# ```

# %%
#To find the default Java path and add export in hadoop-env.sh
JAVA_HOME = !readlink -f /usr/bin/java | sed "s:bin/java::"
java_home_text = JAVA_HOME[0]
java_home_text_command = f"$ {JAVA_HOME[0]} "
# !echo export JAVA_HOME=$java_home_text >>/usr/local/hadoop-3.3.4/etc/hadoop/hadoop-env.sh

# %% [markdown]
# ---
#
# ### Set Hadoop home variables 🏡
#
# I use following command:
# ```
# # Set environment variables
# import os
# os.environ['HADOOP_HOME']="/usr/local/hadoop-3.3.4"
# os.environ['JAVA_HOME']=java_home_text
# ```

# %%
import os
os.environ['HADOOP_HOME']="/usr/local/hadoop-3.3.4"
os.environ['JAVA_HOME']=java_home_text

# %% [markdown]
# ---
#
# ### 1st - Install Pig 🐷
#
# I use following command but you can change to get current last version:
#
# `!wget https://downloads.apache.org/pig/pig-0.17.0/pig-0.17.0.tar.gz`

# %%
# !wget https://downloads.apache.org/pig/pig-0.17.0/pig-0.17.0.tar.gz
# Out:
# --2023-01-26 22:54:54--  https://downloads.apache.org/pig/pig-0.17.0/pig-0.17.0.tar.gz
# Resolving downloads.apache.org (downloads.apache.org)... 88.99.95.219, 135.181.214.104, 2a01:4f8:10a:201a::2, ...
# Connecting to downloads.apache.org (downloads.apache.org)|88.99.95.219|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 230606579 (220M) [application/x-gzip]
# Saving to: ‘pig-0.17.0.tar.gz’
#
# pig-0.17.0.tar.gz   100%[===================>] 219.92M  30.9MB/s    in 7.7s
#
# 2023-01-26 22:55:02 (28.5 MB/s) - ‘pig-0.17.0.tar.gz’ saved [230606579/230606579]

# %% [markdown]
# You would can get other version if you need in: https://downloads.apache.org/pig/ and later replace it in the before command.

# %% [markdown]
# ---
#
# ### 2nd - Unzip and copy 🔓
#
# I use following command:
#
# `!tar -xzvf pig-0.17.0.tar.gz`

# %%
# !tar -xzvf pig-0.17.0.tar.gz

# %% [markdown]
# ---
#
# ### 3rd - Set Pig home variables 🏡
#
# I use following command:
# ```
# # Set environment variables
# import os
# os.environ['PIG_HOME']="/content/pig-0.17.0"
# os.environ['PIG_CLASSPATH']="/usr/local/hadoop-3.3.1/conf"
# os.environ["PATH"] += os.pathsep + "/content/pig-0.17.0/bin"
# ```

# %%
import os
os.environ['PIG_HOME']="/content/pig-0.17.0"
os.environ['PIG_CLASSPATH']="/usr/local/hadoop-3.3.1/conf"
os.environ["PATH"] += os.pathsep + "/content/pig-0.17.0/bin"

# %% [markdown]
# We can validate installation with command:
#
# `!pig -version`

# %%
# !pig -version
# Out:
# Apache Pig version 0.17.0 (r1797386)
# compiled Jun 02 2017, 15:41:58

# %% [markdown]
# ---
#
# ### 4th - Create a folder with HDFS 🌎📂
#
# I use following command:
#
# `!/usr/local/hadoop-3.3.4/bin/hadoop fs -mkdir file:///content/data_pig`

# %%
# !/usr/local/hadoop-3.3.4/bin/hadoop fs -mkdir file:///content/data_pig

# %% [markdown]
# ---
#
# #### 4.1 - Remove folder with HDFS ♻
#
# Maybe, later you need remove it. To do that you must apply following command:
#
# `!/usr/local/hadoop-3.3.4/bin/hadoop fs -rm -r file:///content/data_pig`

# %% [markdown]
# ---
#
# ### 5th - Getting a dataset to anlyze with Pig 💾
#
# I use a dataset from grouplens. You can get other in:
# http://files.grouplens.org/datasets/
#
# This time I use movieslens and you can download it using:
#
# `!wget http://files.grouplens.org/datasets/movielens/ml-100k.zip`

# %%
# !wget http://files.grouplens.org/datasets/movielens/ml-100k.zip
# Out:
# --2023-01-26 23:16:06--  http://files.grouplens.org/datasets/movielens/ml-100k.zip
# Resolving files.grouplens.org (files.grouplens.org)... 128.101.65.152
# Connecting to files.grouplens.org (files.grouplens.org)|128.101.65.152|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4924029 (4.7M) [application/zip]
# Saving to: ‘ml-100k.zip’
#
# ml-100k.zip         100%[===================>]   4.70M  23.2MB/s    in 0.2s
#
# 2023-01-26 23:16:07 (23.2 MB/s) - ‘ml-100k.zip’ saved [4924029/4924029]

# %% [markdown]
# To use data extract files. I extract files in path later of -d in command:
#
# `!unzip "/content/ml-100k.zip" -d "file:///content/data_pig"`

# %%
# !unzip "/content/ml-100k.zip" -d "/content/data_pig"
# Out:
# Archive:  /content/ml-100k.zip
#    creating: /content/data_pig/ml-100k/
#   inflating: /content/data_pig/ml-100k/allbut.pl
#   inflating: /content/data_pig/ml-100k/mku.sh
#   inflating: /content/data_pig/ml-100k/README
#   inflating: /content/data_pig/ml-100k/u.data
#   inflating: /content/data_pig/ml-100k/u.genre
#   inflating: /content/data_pig/ml-100k/u.info
#   inflating: /content/data_pig/ml-100k/u.item
#   inflating: /content/data_pig/ml-100k/u.occupation
#   inflating: /content/data_pig/ml-100k/u.user
#   inflating: /content/data_pig/ml-100k/u1.base
#   inflating: /content/data_pig/ml-100k/u1.test
#   inflating: /content/data_pig/ml-100k/u2.base
#   inflating: /content/data_pig/ml-100k/u2.test
#   inflating: /content/data_pig/ml-100k/u3.base
#   inflating: /content/data_pig/ml-100k/u3.test
#   inflating: /content/data_pig/ml-100k/u4.base
#   inflating: /content/data_pig/ml-100k/u4.test
#   inflating: /content/data_pig/ml-100k/u5.base
#   inflating: /content/data_pig/ml-100k/u5.test
#   inflating: /content/data_pig/ml-100k/ua.base
#   inflating: /content/data_pig/ml-100k/ua.test
#   inflating: /content/data_pig/ml-100k/ub.base
#   inflating: /content/data_pig/ml-100k/ub.test

# %% [markdown]
# For list them:
#
# `!/usr/local/hadoop-3.3.4/bin/hadoop fs -ls /content/data_pig/ml-100k`

# %%
# !/usr/local/hadoop-3.3.4/bin/hadoop fs -ls /content/data_pig/ml-100k
# Out:
# Found 23 items
# -rw-r-----   1 root root       6750 2016-01-29 20:26 /content/data_pig/ml-100k/README
# -rwxr-x---   1 root root        716 2000-07-19 21:09 /content/data_pig/ml-100k/allbut.pl
# -rwxr-x---   1 root root        643 2000-07-19 21:09 /content/data_pig/ml-100k/mku.sh
# -rw-r-----   1 root root    1979173 2000-07-19 21:09 /content/data_pig/ml-100k/u.data
# -rw-r-----   1 root root        202 2000-07-19 21:09 /content/data_pig/ml-100k/u.genre
# -rw-r-----   1 root root         36 2000-07-19 21:09 /content/data_pig/ml-100k/u.info
# -rw-r-----   1 root root     236344 2000-07-19 21:09 /content/data_pig/ml-100k/u.item
# -rw-r-----   1 root root        193 2000-07-19 21:09 /content/data_pig/ml-100k/u.occupation
# -rw-r-----   1 root root      22628 2000-07-19 21:09 /content/data_pig/ml-100k/u.user
# -rw-r-----   1 root root    1586544 2001-03-08 18:33 /content/data_pig/ml-100k/u1.base
# -rw-r-----   1 root root     392629 2001-03-08 18:32 /content/data_pig/ml-100k/u1.test
# -rw-r-----   1 root root    1583948 2001-03-08 18:33 /content/data_pig/ml-100k/u2.base
# -rw-r-----   1 root root     395225 2001-03-08 18:33 /content/data_pig/ml-100k/u2.test
# -rw-r-----   1 root root    1582546 2001-03-08 18:33 /content/data_pig/ml-100k/u3.base
# -rw-r-----   1 root root     396627 2001-03-08 18:33 /content/data_pig/ml-100k/u3.test
# -rw-r-----   1 root root    1581878 2001-03-08 18:33 /content/data_pig/ml-100k/u4.base
# -rw-r-----   1 root root     397295 2001-03-08 18:33 /content/data_pig/ml-100k/u4.test
# -rw-r-----   1 root root    1581776 2001-03-08 18:34 /content/data_pig/ml-100k/u5.base
# -rw-r-----   1 root root     397397 2001-03-08 18:33 /content/data_pig/ml-100k/u5.test
# -rw-r-----   1 root root    1792501 2001-03-08 18:34 /content/data_pig/ml-100k/ua.base
# -rw-r-----   1 root root     186672 2001-03-08 18:34 /content/data_pig/ml-100k/ua.test
# -rw-r-----   1 root root    1792476 2001-03-08 18:34 /content/data_pig/ml-100k/ub.base
# -rw-r-----   1 root root     186697 2001-03-08 18:34 /content/data_pig/ml-100k/ub.test

# %% [markdown]
# ---
#
# ### 6th - Creating process to use Pig with Pig Syntax 🐖
#
# To create job in Pig, you must see structure of dataset to configure jobs.
# In this case we print dataset with following command:
#
# `!head /content/data_pig/ml-100k/u.data`

# %%
# !head /content/data_pig/ml-100k/u.data
# Out:
# 196	242	3	881250949
# 186	302	3	891717742
# 22	377	1	878887116
# 244	51	2	880606923
# 166	346	1	886397596
# 298	474	4	884182806
# 115	265	2	881171488
# 253	465	5	891628467
# 305	451	3	886324817
# 6	86	3	883603013

# %% [markdown]
# I can get following information of dataset:
#
# - First column reference to userID.
# - Second column reference to movieID.
# - Third column reference to rating.
# - Fourth column reference to timestamp.

# %%
# Create pig script
# %%writefile id.pig
/* id.pig */

student = LOAD 'file:///content/data_pig/ml-100k/u.data' USING PigStorage('	')
   as (userId:int, movieId:int, rating:int, timestamp:int);
	
student_order = ORDER student BY rating DESC;
  
Dump student_order;
# Out:
# Overwriting id.pig

# %% [markdown]
# ---
#
# ### 7th - Running the process 🙈
#
# Here we run the process specifing some parameters:
# - Pig file program is `id.pig `
# - Dataset is in `file:///content/data_pig/ml-100k/u.data`
#
# When run process, maybe take a few minutes...
#
# You can run script with:
#
# `!pig -x local id.pig`
#
# But we run script and save results in a file .txt:
#
# `!pig -x local id.pig > results.txt`

# %%
# !pig -x local id.pig > results.txt
# Out:
# 2023-01-26 23:37:04,285 INFO pig.ExecTypeProvider: Trying ExecType : LOCAL
# 2023-01-26 23:37:04,286 INFO pig.ExecTypeProvider: Picked LOCAL as the ExecType
# 2023-01-26 23:37:04,372 [main] INFO  org.apache.pig.Main - Apache Pig version 0.17.0 (r1797386) compiled Jun 02 2017, 15:41:58
# 2023-01-26 23:37:04,372 [main] INFO  org.apache.pig.Main - Logging error messages to: /content/pig_1674776224369.log
# 2023-01-26 23:37:04,387 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - user.name is deprecated. Instead, use mapreduce.job.user.name
# 2023-01-26 23:37:04,550 [main] INFO  org.apache.pig.impl.util.Utils - Default bootup file /root/.pigbootup not found
# 2023-01-26 23:37:04,630 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.job.tracker is deprecated. Instead, use mapreduce.jobtracker.address
# 2023-01-26 23:37:04,632 [main] INFO  org.apache.pig.backend.hadoop.executionengine.HExecutionEngine - Connecting to hadoop file system at: file:///
# 2023-01-26 23:37:04,658 [main] INFO  org.apache.pig.PigServer - Pig Script ID for the session: PIG-id.pig-e28250fd-9d90-4966-9a85-9b68fca2e3e0
# 2023-01-26 23:37:04,658 [main] WARN  org.apache.pig.PigServer - ATS is disabled since yarn.timeline-service.enabled set to false
# 2023-01-26 23:37:05,131 [main] INFO  org.apache.pig.tools.pigstats.ScriptState - Pig features used in the script: ORDER_BY
# 2023-01-26 23:37:05,195 [main] INFO  org.apache.pig.newplan.logical.optimizer.LogicalPlanOptimizer - {RULES_ENABLED=[AddForEach, ColumnMapKeyPrune, ConstantCalculator, GroupByConstParallelSetter, LimitOptimizer, LoadTypeCastInserter, MergeFilter, MergeForEach, NestedLimitOptimizer, PartitionFilterOptimizer, PredicatePushdownOptimizer, PushDownForEachFlatten, PushUpFilter, SplitFilter, StreamTypeCastInserter]}
# 2023-01-26 23:37:05,256 [main] INFO  org.apache.pig.impl.util.SpillableMemoryManager - Selected heap (G1 Old Gen) of size 1048576000 to monitor. collectionUsageThreshold = 734003200, usageThreshold = 734003200
# 2023-01-26 23:37:05,319 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MRCompiler - File concatenation threshold: 100 optimistic? false
# 2023-01-26 23:37:05,372 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.SecondaryKeyOptimizerMR - Using Secondary Key Optimization for MapReduce node scope-20
# 2023-01-26 23:37:05,387 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MultiQueryOptimizer - MR plan size before optimization: 3
# 2023-01-26 23:37:05,387 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MultiQueryOptimizer - MR plan size after optimization: 3
# 2023-01-26 23:37:05,518 [main] INFO  org.apache.hadoop.metrics2.impl.MetricsConfig - Loaded properties from hadoop-metrics2.properties
# 2023-01-26 23:37:05,685 [main] INFO  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - Scheduled Metric snapshot period at 10 second(s).
# 2023-01-26 23:37:05,685 [main] INFO  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system started
# 2023-01-26 23:37:05,719 [main] INFO  org.apache.pig.tools.pigstats.mapreduce.MRScriptState - Pig script settings are added to the job
# 2023-01-26 23:37:05,728 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.job.reduce.markreset.buffer.percent is deprecated. Instead, use mapreduce.reduce.markreset.buffer.percent
# 2023-01-26 23:37:05,729 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler - mapred.job.reduce.markreset.buffer.percent is not set, set to default 0.3
# 2023-01-26 23:37:05,733 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.output.compress is deprecated. Instead, use mapreduce.output.fileoutputformat.compress
# 2023-01-26 23:37:05,753 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler - Setting up single store job
# 2023-01-26 23:37:05,771 [main] INFO  org.apache.pig.data.SchemaTupleFrontend - Key [pig.schematuple] is false, will not generate code.
# 2023-01-26 23:37:05,771 [main] INFO  org.apache.pig.data.SchemaTupleFrontend - Starting process to move generated code to distributed cacche
# 2023-01-26 23:37:05,771 [main] INFO  org.apache.pig.data.SchemaTupleFrontend - Distributed cache not supported or needed in local mode. Setting key [pig.schematuple.local.dir] with code temp directory: /tmp/1674776225770-0
# 2023-01-26 23:37:05,835 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - 1 map-reduce job(s) waiting for submission.
# 2023-01-26 23:37:05,849 [JobControl] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-26 23:37:05,877 [JobControl] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.task.id is deprecated. Instead, use mapreduce.task.attempt.id
# 2023-01-26 23:37:06,005 [JobControl] WARN  org.apache.hadoop.mapreduce.JobResourceUploader - No job jar file set.  User classes may not be found. See Job or Job#setJar(String).
# 2023-01-26 23:37:06,038 [JobControl] INFO  org.apache.pig.builtin.PigStorage - Using PigTextInputFormat
# 2023-01-26 23:37:06,049 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2023-01-26 23:37:06,050 [JobControl] INFO  org.apache.pig.backend.hadoop.executionengine.util.MapRedUtil - Total input paths to process : 1
# 2023-01-26 23:37:06,068 [JobControl] INFO  org.apache.pig.backend.hadoop.executionengine.util.MapRedUtil - Total input paths (combined) to process : 1
# 2023-01-26 23:37:06,118 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - number of splits:1
# 2023-01-26 23:37:06,367 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - Submitting tokens for job: job_local1956899416_0001
# 2023-01-26 23:37:06,367 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - Executing with tokens: []
# 2023-01-26 23:37:06,580 [JobControl] INFO  org.apache.hadoop.mapreduce.Job - The url to track the job: http://localhost:8080/
# 2023-01-26 23:37:06,581 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - HadoopJobId: job_local1956899416_0001
# 2023-01-26 23:37:06,581 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - Processing aliases student
# 2023-01-26 23:37:06,581 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - detailed locations: M: student[3,10],student[-1,-1] C:  R:
# 2023-01-26 23:37:06,606 [Thread-5] INFO  org.apache.hadoop.mapred.LocalJobRunner - OutputCommitter set in config null
# 2023-01-26 23:37:06,613 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - 0% complete
# 2023-01-26 23:37:06,614 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - Running jobs are [job_local1956899416_0001]
# 2023-01-26 23:37:06,660 [Thread-5] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.job.tracker is deprecated. Instead, use mapreduce.jobtracker.address
# 2023-01-26 23:37:06,660 [Thread-5] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.job.reduce.markreset.buffer.percent is deprecated. Instead, use mapreduce.reduce.markreset.buffer.percent
# 2023-01-26 23:37:06,664 [Thread-5] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - File Output Committer Algorithm version is 2
# 2023-01-26 23:37:06,664 [Thread-5] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-01-26 23:37:06,665 [Thread-5] INFO  org.apache.hadoop.mapred.LocalJobRunner - OutputCommitter is org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.PigOutputCommitter
# 2023-01-26 23:37:06,715 [Thread-5] INFO  org.apache.hadoop.mapred.LocalJobRunner - Waiting for map tasks
# 2023-01-26 23:37:06,718 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.LocalJobRunner - Starting task: attempt_local1956899416_0001_m_000000_0
# 2023-01-26 23:37:06,765 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - File Output Committer Algorithm version is 2
# 2023-01-26 23:37:06,765 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-01-26 23:37:06,804 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.Task -  Using ResourceCalculatorProcessTree : [ ]
# 2023-01-26 23:37:06,813 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - Processing split: Number of splits :1
# Total Length = 1979173
# Input split[0]:
#    Length = 1979173
#    ClassName: org.apache.hadoop.mapreduce.lib.input.FileSplit
#    Locations:
#
# -----------------------
#
# 2023-01-26 23:37:06,826 [LocalJobRunner Map Task Executor #0] INFO  org.apache.pig.builtin.PigStorage - Using PigTextInputFormat
# 2023-01-26 23:37:06,832 [LocalJobRunner Map Task Executor #0] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.PigRecordReader - Current split being processed file:/content/data_pig/ml-100k/u.data:0+1979173
# 2023-01-26 23:37:06,842 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - File Output Committer Algorithm version is 2
# 2023-01-26 23:37:06,842 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-01-26 23:37:06,871 [LocalJobRunner Map Task Executor #0] INFO  org.apache.pig.impl.util.SpillableMemoryManager - Selected heap (G1 Old Gen) of size 1048576000 to monitor. collectionUsageThreshold = 734003200, usageThreshold = 734003200
# 2023-01-26 23:37:06,873 [LocalJobRunner Map Task Executor #0] INFO  org.apache.pig.data.SchemaTupleBackend - Key [pig.schematuple] was not set... will not generate code.
# 2023-01-26 23:37:06,891 [LocalJobRunner Map Task Executor #0] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.PigMapOnly$Map - Aliases being processed per job phase (AliasName[line,offset]): M: student[3,10],student[-1,-1] C:  R:
# 2023-01-26 23:37:07,635 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.LocalJobRunner -
# 2023-01-26 23:37:07,642 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.Task - Task:attempt_local1956899416_0001_m_000000_0 is done. And is in the process of committing
# 2023-01-26 23:37:07,649 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.LocalJobRunner -
# 2023-01-26 23:37:07,649 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.Task - Task attempt_local1956899416_0001_m_000000_0 is allowed to commit now
# 2023-01-26 23:37:07,656 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - Saved output of task 'attempt_local1956899416_0001_m_000000_0' to file:/tmp/temp-1095912459/tmp1757708835
# 2023-01-26 23:37:07,657 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.LocalJobRunner - map
# 2023-01-26 23:37:07,657 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.Task - Task 'attempt_local1956899416_0001_m_000000_0' done.
# 2023-01-26 23:37:07,663 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.Task - Final Counters for attempt_local1956899416_0001_m_000000_0: Counters: 15
# 	File System Counters
# 		FILE: Number of bytes read=1979594
# 		FILE: Number of bytes written=2273775
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=100000
# 		Map output records=100000
# 		Input split bytes=364
# 		Spilled Records=0
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=19
# 		Total committed heap usage (bytes)=316669952
# 	File Input Format Counters
# 		Bytes Read=0
# 	File Output Format Counters
# 		Bytes Written=0
# 2023-01-26 23:37:07,663 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.LocalJobRunner - Finishing task: attempt_local1956899416_0001_m_000000_0
# 2023-01-26 23:37:07,665 [Thread-5] INFO  org.apache.hadoop.mapred.LocalJobRunner - map task executor complete.
# 2023-01-26 23:37:07,786 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - 33% complete
# 2023-01-26 23:37:07,791 [main] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-26 23:37:07,803 [main] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-26 23:37:07,804 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.map.tasks is deprecated. Instead, use mapreduce.job.maps
# 2023-01-26 23:37:07,804 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.reduce.tasks is deprecated. Instead, use mapreduce.job.reduces
# 2023-01-26 23:37:07,805 [main] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-26 23:37:07,830 [main] INFO  org.apache.pig.tools.pigstats.mapreduce.MRScriptState - Pig script settings are added to the job
# 2023-01-26 23:37:07,832 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler - mapred.job.reduce.markreset.buffer.percent is not set, set to default 0.3
# 2023-01-26 23:37:07,833 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler - Reduce phase detected, estimating # of required reducers.
# 2023-01-26 23:37:07,833 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler - Using reducer estimator: org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.InputSizeReducerEstimator
# 2023-01-26 23:37:07,836 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.InputSizeReducerEstimator - BytesPerReducer=1000000000 maxReducers=999 totalInputFileSize=1661691
# 2023-01-26 23:37:07,837 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler - Setting Parallelism to 1
# 2023-01-26 23:37:07,840 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler - Setting up single store job
# 2023-01-26 23:37:07,884 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - 1 map-reduce job(s) waiting for submission.
# 2023-01-26 23:37:07,887 [JobControl] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-26 23:37:07,901 [JobControl] WARN  org.apache.hadoop.mapreduce.JobResourceUploader - No job jar file set.  User classes may not be found. See Job or Job#setJar(String).
# 2023-01-26 23:37:07,908 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2023-01-26 23:37:07,908 [JobControl] INFO  org.apache.pig.backend.hadoop.executionengine.util.MapRedUtil - Total input paths to process : 1
# 2023-01-26 23:37:07,909 [JobControl] INFO  org.apache.pig.backend.hadoop.executionengine.util.MapRedUtil - Total input paths (combined) to process : 1
# 2023-01-26 23:37:07,914 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - number of splits:1
# 2023-01-26 23:37:07,930 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - Submitting tokens for job: job_local1424223739_0002
# 2023-01-26 23:37:07,930 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - Executing with tokens: []
# 2023-01-26 23:37:08,026 [JobControl] INFO  org.apache.hadoop.mapreduce.Job - The url to track the job: http://localhost:8080/
# 2023-01-26 23:37:08,027 [Thread-8] INFO  org.apache.hadoop.mapred.LocalJobRunner - OutputCommitter set in config null
# 2023-01-26 23:37:08,039 [Thread-8] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.reduce.tasks is deprecated. Instead, use mapreduce.job.reduces
# 2023-01-26 23:37:08,040 [Thread-8] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.job.tracker is deprecated. Instead, use mapreduce.jobtracker.address
# 2023-01-26 23:37:08,040 [Thread-8] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.job.reduce.markreset.buffer.percent is deprecated. Instead, use mapreduce.reduce.markreset.buffer.percent
# 2023-01-26 23:37:08,040 [Thread-8] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - File Output Committer Algorithm version is 2
# 2023-01-26 23:37:08,040 [Thread-8] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-01-26 23:37:08,043 [Thread-8] INFO  org.apache.hadoop.mapred.LocalJobRunner - OutputCommitter is org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.PigOutputCommitter
# 2023-01-26 23:37:08,052 [Thread-8] INFO  org.apache.hadoop.mapred.LocalJobRunner - Waiting for map tasks
# 2023-01-26 23:37:08,052 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.LocalJobRunner - Starting task: attempt_local1424223739_0002_m_000000_0
# 2023-01-26 23:37:08,062 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - File Output Committer Algorithm version is 2
# 2023-01-26 23:37:08,062 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-01-26 23:37:08,062 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.Task -  Using ResourceCalculatorProcessTree : [ ]
# 2023-01-26 23:37:08,064 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - Processing split: Number of splits :1
# Total Length = 1661691
# Input split[0]:
#    Length = 1661691
#    ClassName: org.apache.hadoop.mapreduce.lib.input.FileSplit
#    Locations:
#
# -----------------------
#
# 2023-01-26 23:37:08,070 [LocalJobRunner Map Task Executor #0] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.PigRecordReader - Current split being processed file:/tmp/temp-1095912459/tmp1757708835/part-m-00000:0+1661691
# 2023-01-26 23:37:08,207 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - (EQUATOR) 0 kvi 26214396(104857584)
# 2023-01-26 23:37:08,207 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - mapreduce.task.io.sort.mb: 100
# 2023-01-26 23:37:08,207 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - soft limit at 83886080
# 2023-01-26 23:37:08,207 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - bufstart = 0; bufvoid = 104857600
# 2023-01-26 23:37:08,207 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - kvstart = 26214396; length = 6553600
# 2023-01-26 23:37:08,212 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2023-01-26 23:37:08,216 [LocalJobRunner Map Task Executor #0] INFO  org.apache.pig.impl.util.SpillableMemoryManager - Selected heap (G1 Old Gen) of size 1048576000 to monitor. collectionUsageThreshold = 734003200, usageThreshold = 734003200
# 2023-01-26 23:37:08,217 [LocalJobRunner Map Task Executor #0] WARN  org.apache.pig.data.SchemaTupleBackend - SchemaTupleBackend has already been initialized
# 2023-01-26 23:37:08,219 [LocalJobRunner Map Task Executor #0] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.PigGenericMapReduce$Map - Aliases being processed per job phase (AliasName[line,offset]): M: student_order[6,16] C:  R:
# 2023-01-26 23:37:08,353 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.LocalJobRunner -
# 2023-01-26 23:37:08,353 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - Starting flush of map output
# 2023-01-26 23:37:08,353 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - Spilling map output
# 2023-01-26 23:37:08,353 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - bufstart = 0; bufend = 1586; bufvoid = 104857600
# 2023-01-26 23:37:08,353 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - kvstart = 26214396(104857584); kvend = 26214000(104856000); length = 397/6553600
# 2023-01-26 23:37:08,363 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - Finished spill 0
# 2023-01-26 23:37:08,366 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.Task - Task:attempt_local1424223739_0002_m_000000_0 is done. And is in the process of committing
# 2023-01-26 23:37:08,367 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.LocalJobRunner - map
# 2023-01-26 23:37:08,367 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.Task - Task 'attempt_local1424223739_0002_m_000000_0' done.
# 2023-01-26 23:37:08,367 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.Task - Final Counters for attempt_local1424223739_0002_m_000000_0: Counters: 17
# 	File System Counters
# 		FILE: Number of bytes read=3654717
# 		FILE: Number of bytes written=2892050
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=100
# 		Map output records=100
# 		Map output bytes=1586
# 		Map output materialized bytes=1792
# 		Input split bytes=379
# 		Combine input records=0
# 		Spilled Records=100
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=316669952
# 	File Input Format Counters
# 		Bytes Read=0
# 2023-01-26 23:37:08,368 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.LocalJobRunner - Finishing task: attempt_local1424223739_0002_m_000000_0
# 2023-01-26 23:37:08,368 [Thread-8] INFO  org.apache.hadoop.mapred.LocalJobRunner - map task executor complete.
# 2023-01-26 23:37:08,370 [Thread-8] INFO  org.apache.hadoop.mapred.LocalJobRunner - Waiting for reduce tasks
# 2023-01-26 23:37:08,372 [pool-6-thread-1] INFO  org.apache.hadoop.mapred.LocalJobRunner - Starting task: attempt_local1424223739_0002_r_000000_0
# 2023-01-26 23:37:08,386 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - HadoopJobId: job_local1424223739_0002
# 2023-01-26 23:37:08,386 [pool-6-thread-1] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - File Output Committer Algorithm version is 2
# 2023-01-26 23:37:08,386 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - Processing aliases student_order
# 2023-01-26 23:37:08,386 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - detailed locations: M: student_order[6,16] C:  R:
# 2023-01-26 23:37:08,386 [pool-6-thread-1] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-01-26 23:37:08,390 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - 50% complete
# 2023-01-26 23:37:08,390 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - Running jobs are [job_local1424223739_0002]
# 2023-01-26 23:37:08,394 [pool-6-thread-1] INFO  org.apache.hadoop.mapred.Task -  Using ResourceCalculatorProcessTree : [ ]
# 2023-01-26 23:37:08,397 [pool-6-thread-1] INFO  org.apache.hadoop.mapred.ReduceTask - Using ShuffleConsumerPlugin: org.apache.hadoop.mapreduce.task.reduce.Shuffle@15ab24cc
# 2023-01-26 23:37:08,399 [pool-6-thread-1] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-26 23:37:08,419 [pool-6-thread-1] INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl - MergerManager: memoryLimit=734003200, maxSingleShuffleLimit=183500800, mergeThreshold=484442144, ioSortFactor=10, memToMemMergeOutputsThreshold=10
# 2023-01-26 23:37:08,436 [EventFetcher for fetching Map Completion Events] INFO  org.apache.hadoop.mapreduce.task.reduce.EventFetcher - attempt_local1424223739_0002_r_000000_0 Thread started: EventFetcher for fetching Map Completion Events
# 2023-01-26 23:37:08,466 [localfetcher#1] INFO  org.apache.hadoop.mapreduce.task.reduce.LocalFetcher - localfetcher#1 about to shuffle output of map attempt_local1424223739_0002_m_000000_0 decomp: 1788 len: 1792 to MEMORY
# 2023-01-26 23:37:08,471 [localfetcher#1] INFO  org.apache.hadoop.mapreduce.task.reduce.InMemoryMapOutput - Read 1788 bytes from map-output for attempt_local1424223739_0002_m_000000_0
# 2023-01-26 23:37:08,472 [localfetcher#1] INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl - closeInMemoryFile -> map-output of size: 1788, inMemoryMapOutputs.size() -> 1, commitMemory -> 0, usedMemory ->1788
# 2023-01-26 23:37:08,477 [EventFetcher for fetching Map Completion Events] INFO  org.apache.hadoop.mapreduce.task.reduce.EventFetcher - EventFetcher is interrupted.. Returning
# 2023-01-26 23:37:08,478 [pool-6-thread-1] INFO  org.apache.hadoop.mapred.LocalJobRunner - 1 / 1 copied.
# 2023-01-26 23:37:08,478 [pool-6-thread-1] INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl - finalMerge called with 1 in-memory map-outputs and 0 on-disk map-outputs
# 2023-01-26 23:37:08,484 [pool-6-thread-1] INFO  org.apache.hadoop.mapred.Merger - Merging 1 sorted segments
# 2023-01-26 23:37:08,484 [pool-6-thread-1] INFO  org.apache.hadoop.mapred.Merger - Down to the last merge-pass, with 1 segments left of total size: 1775 bytes
# 2023-01-26 23:37:08,489 [pool-6-thread-1] INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl - Merged 1 segments, 1788 bytes to disk to satisfy reduce memory limit
# 2023-01-26 23:37:08,490 [pool-6-thread-1] INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl - Merging 1 files, 1792 bytes from disk
# 2023-01-26 23:37:08,491 [pool-6-thread-1] INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl - Merging 0 segments, 0 bytes from memory into reduce
# 2023-01-26 23:37:08,491 [pool-6-thread-1] INFO  org.apache.hadoop.mapred.Merger - Merging 1 sorted segments
# 2023-01-26 23:37:08,492 [pool-6-thread-1] INFO  org.apache.hadoop.mapred.Merger - Down to the last merge-pass, with 1 segments left of total size: 1775 bytes
# 2023-01-26 23:37:08,492 [pool-6-thread-1] INFO  org.apache.hadoop.mapred.LocalJobRunner - 1 / 1 copied.
# 2023-01-26 23:37:08,499 [pool-6-thread-1] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - File Output Committer Algorithm version is 2
# 2023-01-26 23:37:08,499 [pool-6-thread-1] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-01-26 23:37:08,500 [pool-6-thread-1] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.skip.on is deprecated. Instead, use mapreduce.job.skiprecords
# 2023-01-26 23:37:08,504 [pool-6-thread-1] INFO  org.apache.pig.impl.util.SpillableMemoryManager - Selected heap (G1 Old Gen) of size 1048576000 to monitor. collectionUsageThreshold = 734003200, usageThreshold = 734003200
# 2023-01-26 23:37:08,504 [pool-6-thread-1] WARN  org.apache.pig.data.SchemaTupleBackend - SchemaTupleBackend has already been initialized
# 2023-01-26 23:37:08,510 [pool-6-thread-1] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.PigMapReduce$Reduce - Aliases being processed per job phase (AliasName[line,offset]): M: student_order[6,16] C:  R:
# 2023-01-26 23:37:08,523 [pool-6-thread-1] INFO  org.apache.hadoop.mapred.Task - Task:attempt_local1424223739_0002_r_000000_0 is done. And is in the process of committing
# 2023-01-26 23:37:08,527 [pool-6-thread-1] INFO  org.apache.hadoop.mapred.LocalJobRunner - 1 / 1 copied.
# 2023-01-26 23:37:08,527 [pool-6-thread-1] INFO  org.apache.hadoop.mapred.Task - Task attempt_local1424223739_0002_r_000000_0 is allowed to commit now
# 2023-01-26 23:37:08,532 [pool-6-thread-1] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - Saved output of task 'attempt_local1424223739_0002_r_000000_0' to file:/tmp/temp-1095912459/tmp1092658312
# 2023-01-26 23:37:08,533 [pool-6-thread-1] INFO  org.apache.hadoop.mapred.LocalJobRunner - reduce > reduce
# 2023-01-26 23:37:08,533 [pool-6-thread-1] INFO  org.apache.hadoop.mapred.Task - Task 'attempt_local1424223739_0002_r_000000_0' done.
# 2023-01-26 23:37:08,533 [pool-6-thread-1] INFO  org.apache.hadoop.mapred.Task - Final Counters for attempt_local1424223739_0002_r_000000_0: Counters: 24
# 	File System Counters
# 		FILE: Number of bytes read=3658333
# 		FILE: Number of bytes written=2893903
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=1
# 		Reduce shuffle bytes=1792
# 		Reduce input records=100
# 		Reduce output records=1
# 		Spilled Records=100
# 		Shuffled Maps =1
# 		Failed Shuffles=0
# 		Merged Map outputs=1
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=316669952
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Output Format Counters
# 		Bytes Written=0
# 2023-01-26 23:37:08,533 [pool-6-thread-1] INFO  org.apache.hadoop.mapred.LocalJobRunner - Finishing task: attempt_local1424223739_0002_r_000000_0
# 2023-01-26 23:37:08,533 [Thread-8] INFO  org.apache.hadoop.mapred.LocalJobRunner - reduce task executor complete.
# 2023-01-26 23:37:08,729 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - 66% complete
# 2023-01-26 23:37:08,733 [main] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-26 23:37:08,736 [main] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-26 23:37:08,738 [main] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-26 23:37:08,750 [main] INFO  org.apache.pig.tools.pigstats.mapreduce.MRScriptState - Pig script settings are added to the job
# 2023-01-26 23:37:08,750 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler - mapred.job.reduce.markreset.buffer.percent is not set, set to default 0.3
# 2023-01-26 23:37:08,751 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler - Reduce phase detected, estimating # of required reducers.
# 2023-01-26 23:37:08,751 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler - Setting Parallelism to 1
# 2023-01-26 23:37:08,753 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler - Setting up single store job
# 2023-01-26 23:37:08,779 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - 1 map-reduce job(s) waiting for submission.
# 2023-01-26 23:37:08,781 [JobControl] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-26 23:37:08,792 [JobControl] WARN  org.apache.hadoop.mapreduce.JobResourceUploader - No job jar file set.  User classes may not be found. See Job or Job#setJar(String).
# 2023-01-26 23:37:08,800 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2023-01-26 23:37:08,800 [JobControl] INFO  org.apache.pig.backend.hadoop.executionengine.util.MapRedUtil - Total input paths to process : 1
# 2023-01-26 23:37:08,800 [JobControl] INFO  org.apache.pig.backend.hadoop.executionengine.util.MapRedUtil - Total input paths (combined) to process : 1
# 2023-01-26 23:37:08,804 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - number of splits:1
# 2023-01-26 23:37:08,825 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - Submitting tokens for job: job_local1532154512_0003
# 2023-01-26 23:37:08,825 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - Executing with tokens: []
# 2023-01-26 23:37:08,924 [JobControl] INFO  org.apache.hadoop.mapreduce.Job - The url to track the job: http://localhost:8080/
# 2023-01-26 23:37:08,925 [Thread-15] INFO  org.apache.hadoop.mapred.LocalJobRunner - OutputCommitter set in config null
# 2023-01-26 23:37:08,932 [Thread-15] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.reduce.tasks is deprecated. Instead, use mapreduce.job.reduces
# 2023-01-26 23:37:08,932 [Thread-15] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.job.tracker is deprecated. Instead, use mapreduce.jobtracker.address
# 2023-01-26 23:37:08,932 [Thread-15] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.job.reduce.markreset.buffer.percent is deprecated. Instead, use mapreduce.reduce.markreset.buffer.percent
# 2023-01-26 23:37:08,933 [Thread-15] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - File Output Committer Algorithm version is 2
# 2023-01-26 23:37:08,933 [Thread-15] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-01-26 23:37:08,933 [Thread-15] INFO  org.apache.hadoop.mapred.LocalJobRunner - OutputCommitter is org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.PigOutputCommitter
# 2023-01-26 23:37:08,938 [Thread-15] INFO  org.apache.hadoop.mapred.LocalJobRunner - Waiting for map tasks
# 2023-01-26 23:37:08,938 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.LocalJobRunner - Starting task: attempt_local1532154512_0003_m_000000_0
# 2023-01-26 23:37:08,947 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - File Output Committer Algorithm version is 2
# 2023-01-26 23:37:08,947 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-01-26 23:37:08,947 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.Task -  Using ResourceCalculatorProcessTree : [ ]
# 2023-01-26 23:37:08,950 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - Processing split: Number of splits :1
# Total Length = 1661691
# Input split[0]:
#    Length = 1661691
#    ClassName: org.apache.hadoop.mapreduce.lib.input.FileSplit
#    Locations:
#
# -----------------------
#
# 2023-01-26 23:37:08,952 [LocalJobRunner Map Task Executor #0] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.PigRecordReader - Current split being processed file:/tmp/temp-1095912459/tmp1757708835/part-m-00000:0+1661691
# 2023-01-26 23:37:08,976 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - (EQUATOR) 0 kvi 26214396(104857584)
# 2023-01-26 23:37:08,976 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - mapreduce.task.io.sort.mb: 100
# 2023-01-26 23:37:08,976 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - soft limit at 83886080
# 2023-01-26 23:37:08,976 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - bufstart = 0; bufvoid = 104857600
# 2023-01-26 23:37:08,976 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - kvstart = 26214396; length = 6553600
# 2023-01-26 23:37:08,998 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2023-01-26 23:37:09,001 [LocalJobRunner Map Task Executor #0] INFO  org.apache.pig.impl.util.SpillableMemoryManager - Selected heap (G1 Old Gen) of size 1048576000 to monitor. collectionUsageThreshold = 734003200, usageThreshold = 734003200
# 2023-01-26 23:37:09,001 [LocalJobRunner Map Task Executor #0] WARN  org.apache.pig.data.SchemaTupleBackend - SchemaTupleBackend has already been initialized
# 2023-01-26 23:37:09,003 [LocalJobRunner Map Task Executor #0] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.PigGenericMapReduce$Map - Aliases being processed per job phase (AliasName[line,offset]): M: student_order[6,16] C:  R:
# 2023-01-26 23:37:09,281 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - HadoopJobId: job_local1532154512_0003
# 2023-01-26 23:37:09,281 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - Processing aliases student_order
# 2023-01-26 23:37:09,281 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - detailed locations: M: student_order[6,16] C:  R:
# 2023-01-26 23:37:09,389 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.LocalJobRunner -
# 2023-01-26 23:37:09,389 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - Starting flush of map output
# 2023-01-26 23:37:09,389 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - Spilling map output
# 2023-01-26 23:37:09,389 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - bufstart = 0; bufend = 1967801; bufvoid = 104857600
# 2023-01-26 23:37:09,389 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - kvstart = 26214396(104857584); kvend = 25814400(103257600); length = 399997/6553600
# 2023-01-26 23:37:09,544 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - Finished spill 0
# 2023-01-26 23:37:09,546 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.Task - Task:attempt_local1532154512_0003_m_000000_0 is done. And is in the process of committing
# 2023-01-26 23:37:09,548 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.LocalJobRunner - map
# 2023-01-26 23:37:09,548 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.Task - Task 'attempt_local1532154512_0003_m_000000_0' done.
# 2023-01-26 23:37:09,548 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.Task - Final Counters for attempt_local1532154512_0003_m_000000_0: Counters: 17
# 	File System Counters
# 		FILE: Number of bytes read=5333456
# 		FILE: Number of bytes written=5673137
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=100000
# 		Map output records=100000
# 		Map output bytes=1967801
# 		Map output materialized bytes=2167807
# 		Input split bytes=379
# 		Combine input records=0
# 		Spilled Records=100000
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=14
# 		Total committed heap usage (bytes)=316669952
# 	File Input Format Counters
# 		Bytes Read=0
# 2023-01-26 23:37:09,548 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.LocalJobRunner - Finishing task: attempt_local1532154512_0003_m_000000_0
# 2023-01-26 23:37:09,548 [Thread-15] INFO  org.apache.hadoop.mapred.LocalJobRunner - map task executor complete.
# 2023-01-26 23:37:09,551 [Thread-15] INFO  org.apache.hadoop.mapred.LocalJobRunner - Waiting for reduce tasks
# 2023-01-26 23:37:09,553 [pool-11-thread-1] INFO  org.apache.hadoop.mapred.LocalJobRunner - Starting task: attempt_local1532154512_0003_r_000000_0
# 2023-01-26 23:37:09,565 [pool-11-thread-1] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - File Output Committer Algorithm version is 2
# 2023-01-26 23:37:09,565 [pool-11-thread-1] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-01-26 23:37:09,568 [pool-11-thread-1] INFO  org.apache.hadoop.mapred.Task -  Using ResourceCalculatorProcessTree : [ ]
# 2023-01-26 23:37:09,568 [pool-11-thread-1] INFO  org.apache.hadoop.mapred.ReduceTask - Using ShuffleConsumerPlugin: org.apache.hadoop.mapreduce.task.reduce.Shuffle@6cf19139
# 2023-01-26 23:37:09,568 [pool-11-thread-1] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-26 23:37:09,569 [pool-11-thread-1] INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl - MergerManager: memoryLimit=734003200, maxSingleShuffleLimit=183500800, mergeThreshold=484442144, ioSortFactor=10, memToMemMergeOutputsThreshold=10
# 2023-01-26 23:37:09,573 [EventFetcher for fetching Map Completion Events] INFO  org.apache.hadoop.mapreduce.task.reduce.EventFetcher - attempt_local1532154512_0003_r_000000_0 Thread started: EventFetcher for fetching Map Completion Events
# 2023-01-26 23:37:09,575 [localfetcher#2] INFO  org.apache.hadoop.mapreduce.task.reduce.LocalFetcher - localfetcher#2 about to shuffle output of map attempt_local1532154512_0003_m_000000_0 decomp: 2167803 len: 2167807 to MEMORY
# 2023-01-26 23:37:09,579 [localfetcher#2] INFO  org.apache.hadoop.mapreduce.task.reduce.InMemoryMapOutput - Read 2167803 bytes from map-output for attempt_local1532154512_0003_m_000000_0
# 2023-01-26 23:37:09,579 [localfetcher#2] INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl - closeInMemoryFile -> map-output of size: 2167803, inMemoryMapOutputs.size() -> 1, commitMemory -> 0, usedMemory ->2167803
# 2023-01-26 23:37:09,582 [EventFetcher for fetching Map Completion Events] INFO  org.apache.hadoop.mapreduce.task.reduce.EventFetcher - EventFetcher is interrupted.. Returning
# 2023-01-26 23:37:09,582 [pool-11-thread-1] INFO  org.apache.hadoop.mapred.LocalJobRunner - 1 / 1 copied.
# 2023-01-26 23:37:09,583 [pool-11-thread-1] INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl - finalMerge called with 1 in-memory map-outputs and 0 on-disk map-outputs
# 2023-01-26 23:37:09,585 [pool-11-thread-1] INFO  org.apache.hadoop.mapred.Merger - Merging 1 sorted segments
# 2023-01-26 23:37:09,585 [pool-11-thread-1] INFO  org.apache.hadoop.mapred.Merger - Down to the last merge-pass, with 1 segments left of total size: 2167795 bytes
# 2023-01-26 23:37:09,698 [pool-11-thread-1] INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl - Merged 1 segments, 2167803 bytes to disk to satisfy reduce memory limit
# 2023-01-26 23:37:09,699 [pool-11-thread-1] INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl - Merging 1 files, 2167807 bytes from disk
# 2023-01-26 23:37:09,699 [pool-11-thread-1] INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl - Merging 0 segments, 0 bytes from memory into reduce
# 2023-01-26 23:37:09,699 [pool-11-thread-1] INFO  org.apache.hadoop.mapred.Merger - Merging 1 sorted segments
# 2023-01-26 23:37:09,699 [pool-11-thread-1] INFO  org.apache.hadoop.mapred.Merger - Down to the last merge-pass, with 1 segments left of total size: 2167795 bytes
# 2023-01-26 23:37:09,700 [pool-11-thread-1] INFO  org.apache.hadoop.mapred.LocalJobRunner - 1 / 1 copied.
# 2023-01-26 23:37:09,703 [pool-11-thread-1] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - File Output Committer Algorithm version is 2
# 2023-01-26 23:37:09,703 [pool-11-thread-1] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-01-26 23:37:09,705 [pool-11-thread-1] INFO  org.apache.pig.impl.util.SpillableMemoryManager - Selected heap (G1 Old Gen) of size 1048576000 to monitor. collectionUsageThreshold = 734003200, usageThreshold = 734003200
# 2023-01-26 23:37:09,705 [pool-11-thread-1] WARN  org.apache.pig.data.SchemaTupleBackend - SchemaTupleBackend has already been initialized
# 2023-01-26 23:37:09,707 [pool-11-thread-1] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.PigMapReduce$Reduce - Aliases being processed per job phase (AliasName[line,offset]): M: student_order[6,16] C:  R:
# 2023-01-26 23:37:09,785 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - 83% complete
# 2023-01-26 23:37:09,785 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - Running jobs are [job_local1532154512_0003]
# 2023-01-26 23:37:10,081 [pool-11-thread-1] INFO  org.apache.hadoop.mapred.Task - Task:attempt_local1532154512_0003_r_000000_0 is done. And is in the process of committing
# 2023-01-26 23:37:10,085 [pool-11-thread-1] INFO  org.apache.hadoop.mapred.LocalJobRunner - 1 / 1 copied.
# 2023-01-26 23:37:10,085 [pool-11-thread-1] INFO  org.apache.hadoop.mapred.Task - Task attempt_local1532154512_0003_r_000000_0 is allowed to commit now
# 2023-01-26 23:37:10,090 [pool-11-thread-1] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - Saved output of task 'attempt_local1532154512_0003_r_000000_0' to file:/tmp/temp-1095912459/tmp804691127
# 2023-01-26 23:37:10,091 [pool-11-thread-1] INFO  org.apache.hadoop.mapred.LocalJobRunner - reduce > reduce
# 2023-01-26 23:37:10,091 [pool-11-thread-1] INFO  org.apache.hadoop.mapred.Task - Task 'attempt_local1532154512_0003_r_000000_0' done.
# 2023-01-26 23:37:10,092 [pool-11-thread-1] INFO  org.apache.hadoop.mapred.Task - Final Counters for attempt_local1532154512_0003_r_000000_0: Counters: 24
# 	File System Counters
# 		FILE: Number of bytes read=9669102
# 		FILE: Number of bytes written=9515627
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=5
# 		Reduce shuffle bytes=2167807
# 		Reduce input records=100000
# 		Reduce output records=100000
# 		Spilled Records=100000
# 		Shuffled Maps =1
# 		Failed Shuffles=0
# 		Merged Map outputs=1
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=316669952
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Output Format Counters
# 		Bytes Written=0
# 2023-01-26 23:37:10,092 [pool-11-thread-1] INFO  org.apache.hadoop.mapred.LocalJobRunner - Finishing task: attempt_local1532154512_0003_r_000000_0
# 2023-01-26 23:37:10,092 [Thread-15] INFO  org.apache.hadoop.mapred.LocalJobRunner - reduce task executor complete.
# 2023-01-26 23:37:10,231 [main] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-26 23:37:10,233 [main] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-26 23:37:10,234 [main] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-26 23:37:10,242 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - 100% complete
# 2023-01-26 23:37:10,247 [main] INFO  org.apache.pig.tools.pigstats.mapreduce.SimplePigStats - Script Statistics:
#
# HadoopVersion	PigVersion	UserId	StartedAt	FinishedAt	Features
# 3.3.4	0.17.0	root	2023-01-26 23:37:05	2023-01-26 23:37:10	ORDER_BY
#
# Success!
#
# Job Stats (time in seconds):
# JobId	Maps	Reduces	MaxMapTime	MinMapTime	AvgMapTime	MedianMapTime	MaxReduceTime	MinReduceTime	AvgReduceTime	MedianReducetime	Alias	Feature	Outputs
# job_local1424223739_0002	1	1	n/a	n/a	n/a	n/a	n/a	n/a	n/a	n/a	student_order	SAMPLER
# job_local1532154512_0003	1	1	n/a	n/a	n/a	n/a	n/a	n/a	n/a	n/a	student_order	ORDER_BY	file:/tmp/temp-1095912459/tmp804691127,
# job_local1956899416_0001	1	0	n/a	n/a	n/a	n/a	0	0	0	0	student	MAP_ONLY
#
# Input(s):
# Successfully read 100000 records from: "file:///content/data_pig/ml-100k/u.data"
#
# Output(s):
# Successfully stored 100000 records in: "file:/tmp/temp-1095912459/tmp804691127"
#
# Counters:
# Total records written : 100000
# Total bytes written : 0
# Spillable Memory Manager spill count : 0
# Total bags proactively spilled: 0
# Total records proactively spilled: 0
#
# Job DAG:
# job_local1956899416_0001	->	job_local1424223739_0002,
# job_local1424223739_0002	->	job_local1532154512_0003,
# job_local1532154512_0003
#
#
# 2023-01-26 23:37:10,248 [main] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-26 23:37:10,250 [main] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-26 23:37:10,251 [main] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-26 23:37:10,258 [main] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-26 23:37:10,262 [main] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-26 23:37:10,263 [main] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-26 23:37:10,268 [main] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-26 23:37:10,270 [main] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-26 23:37:10,271 [main] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-26 23:37:10,274 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - Success!
# 2023-01-26 23:37:10,278 [main] WARN  org.apache.pig.data.SchemaTupleBackend - SchemaTupleBackend has already been initialized
# 2023-01-26 23:37:10,280 [main] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2023-01-26 23:37:10,280 [main] INFO  org.apache.pig.backend.hadoop.executionengine.util.MapRedUtil - Total input paths to process : 1
# 2023-01-26 23:37:10,906 [main] INFO  org.apache.pig.Main - Pig script completed in 6 seconds and 834 milliseconds (6834 ms)

# %% [markdown]
# In next step I list head and tail of file to see if script it worked.

# %%
# !head results.txt
# !tail results.txt
# Out:
# (301,69,5,882076682)
# (389,100,5,879915701)
# (29,12,5,882821989)
# (507,405,5,889966127)
# (527,238,5,879456405)
# (216,302,5,881966913)
# (160,24,5,876769689)
# (577,866,5,880470570)
# (13,867,5,882399615)
# (58,228,5,884305271)
# (405,679,1,885547997)
# (601,294,1,876346515)
# (445,831,1,891200447)
# (474,756,1,887915646)
# (865,472,1,880144229)
# (405,1224,1,885546487)
# (21,299,1,874950931)
# (181,1282,1,878962496)
# (15,235,1,879456424)
# (23,294,1,876785901)

# %% [markdown]
# Effectively script it worked.
# We see rating is ordered.

# %% [markdown]
# ---
#
# ### 8th - Advancing in the logic of the scripts 😎
#
# Now we will advance in logic of the script to get answer to next questions:
# - What are the oldest 5 star movies?
# - What are the worst movies?

# %% [markdown]
# ---
#
# #### 8.1 - Find oldest 5 star movies start ⭐

# %%
# %%writefile fiveStarMovies.pig
#
# ratings = LOAD 'file:///content/data_pig/ml-100k/u.data'
# 	AS (userID:int, movieID:int, rating:int, ratingTime:int);
# metadata = LOAD 'file:///content/data_pig/ml-100k/u.item' USING PigStorage('|')
# 	AS (movieID:int, movieTitle:chararray, releaseDate:chararray, videoRealese:chararray, imdblink:chararray);
#
# nameLookup = FOREACH metadata GENERATE movieID, movieTitle,	ToUnixTime(ToDate(releaseDate, 'dd-MMM-yyyy')) AS releaseTime;
#
# ratingsByMovie = GROUP ratings BY movieID;
#
# avgRatings = FOREACH ratingsByMovie GENERATE group as movieID, AVG(ratings.rating) as avgRating;
#
# fiveStarMovies = FILTER avgRatings BY avgRating > 4.0;
#
# fiveStarsWithData = JOIN fiveStarMovies BY movieID, nameLookup BY movieID;
#
# oldestFiveStarMovies = ORDER fiveStarsWithData BY nameLookup::releaseTime;
#
# DUMP oldestFiveStarMovies;
# Out:
# Overwriting fiveStarMovies.pig

# %% [markdown]
# Run script and save results in a file .txt:
#
# `!pig -x local fiveStarMovies.pig > fiveStarMovies.txt`

# %%
# !pig -x local fiveStarMovies.pig > fiveStarMovies.txt
# Out:
# 2023-01-27 00:10:13,618 INFO pig.ExecTypeProvider: Trying ExecType : LOCAL
# 2023-01-27 00:10:13,619 INFO pig.ExecTypeProvider: Picked LOCAL as the ExecType
# 2023-01-27 00:10:13,686 [main] INFO  org.apache.pig.Main - Apache Pig version 0.17.0 (r1797386) compiled Jun 02 2017, 15:41:58
# 2023-01-27 00:10:13,686 [main] INFO  org.apache.pig.Main - Logging error messages to: /content/pig_1674778213682.log
# 2023-01-27 00:10:13,704 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - user.name is deprecated. Instead, use mapreduce.job.user.name
# 2023-01-27 00:10:13,883 [main] INFO  org.apache.pig.impl.util.Utils - Default bootup file /root/.pigbootup not found
# 2023-01-27 00:10:13,974 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.job.tracker is deprecated. Instead, use mapreduce.jobtracker.address
# 2023-01-27 00:10:13,977 [main] INFO  org.apache.pig.backend.hadoop.executionengine.HExecutionEngine - Connecting to hadoop file system at: file:///
# 2023-01-27 00:10:14,004 [main] INFO  org.apache.pig.PigServer - Pig Script ID for the session: PIG-fiveStarMovies.pig-de248985-926c-4d74-bd9e-4b5a1b8f29f5
# 2023-01-27 00:10:14,004 [main] WARN  org.apache.pig.PigServer - ATS is disabled since yarn.timeline-service.enabled set to false
# 2023-01-27 00:10:14,673 [main] INFO  org.apache.pig.impl.util.SpillableMemoryManager - Selected heap (G1 Old Gen) of size 1048576000 to monitor. collectionUsageThreshold = 734003200, usageThreshold = 734003200
# 2023-01-27 00:10:14,690 [main] INFO  org.apache.pig.tools.pigstats.ScriptState - Pig features used in the script: HASH_JOIN,GROUP_BY,ORDER_BY,FILTER
# 2023-01-27 00:10:14,742 [main] INFO  org.apache.pig.newplan.logical.optimizer.LogicalPlanOptimizer - {RULES_ENABLED=[AddForEach, ColumnMapKeyPrune, ConstantCalculator, GroupByConstParallelSetter, LimitOptimizer, LoadTypeCastInserter, MergeFilter, MergeForEach, NestedLimitOptimizer, PartitionFilterOptimizer, PredicatePushdownOptimizer, PushDownForEachFlatten, PushUpFilter, SplitFilter, StreamTypeCastInserter]}
# 2023-01-27 00:10:14,765 [main] INFO  org.apache.pig.newplan.logical.rules.ColumnPruneVisitor - Columns pruned for metadata: $3, $4
# 2023-01-27 00:10:14,840 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MRCompiler - File concatenation threshold: 100 optimistic? false
# 2023-01-27 00:10:14,856 [main] INFO  org.apache.pig.backend.hadoop.executionengine.util.CombinerOptimizerUtil - Choosing to move algebraic foreach to combiner
# 2023-01-27 00:10:14,867 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.SecondaryKeyOptimizerMR - Using Secondary Key Optimization for MapReduce node scope-66
# 2023-01-27 00:10:14,870 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MRCompiler$LastInputStreamingOptimizer - Rewrite: POPackage->POForEach to POPackage(JoinPackager)
# 2023-01-27 00:10:14,883 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MultiQueryOptimizer - MR plan size before optimization: 4
# 2023-01-27 00:10:14,883 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MultiQueryOptimizer - MR plan size after optimization: 4
# 2023-01-27 00:10:14,979 [main] INFO  org.apache.hadoop.metrics2.impl.MetricsConfig - Loaded properties from hadoop-metrics2.properties
# 2023-01-27 00:10:15,065 [main] INFO  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - Scheduled Metric snapshot period at 10 second(s).
# 2023-01-27 00:10:15,066 [main] INFO  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system started
# 2023-01-27 00:10:15,086 [main] INFO  org.apache.pig.tools.pigstats.mapreduce.MRScriptState - Pig script settings are added to the job
# 2023-01-27 00:10:15,105 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.job.reduce.markreset.buffer.percent is deprecated. Instead, use mapreduce.reduce.markreset.buffer.percent
# 2023-01-27 00:10:15,108 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler - mapred.job.reduce.markreset.buffer.percent is not set, set to default 0.3
# 2023-01-27 00:10:15,109 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.output.compress is deprecated. Instead, use mapreduce.output.fileoutputformat.compress
# 2023-01-27 00:10:15,116 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler - Reduce phase detected, estimating # of required reducers.
# 2023-01-27 00:10:15,117 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler - Using reducer estimator: org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.InputSizeReducerEstimator
# 2023-01-27 00:10:15,133 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.InputSizeReducerEstimator - BytesPerReducer=1000000000 maxReducers=999 totalInputFileSize=1979173
# 2023-01-27 00:10:15,133 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler - Setting Parallelism to 1
# 2023-01-27 00:10:15,133 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.reduce.tasks is deprecated. Instead, use mapreduce.job.reduces
# 2023-01-27 00:10:15,149 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler - Setting up single store job
# 2023-01-27 00:10:15,157 [main] INFO  org.apache.pig.data.SchemaTupleFrontend - Key [pig.schematuple] is false, will not generate code.
# 2023-01-27 00:10:15,157 [main] INFO  org.apache.pig.data.SchemaTupleFrontend - Starting process to move generated code to distributed cacche
# 2023-01-27 00:10:15,157 [main] INFO  org.apache.pig.data.SchemaTupleFrontend - Distributed cache not supported or needed in local mode. Setting key [pig.schematuple.local.dir] with code temp directory: /tmp/1674778215157-0
# 2023-01-27 00:10:15,268 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - 1 map-reduce job(s) waiting for submission.
# 2023-01-27 00:10:15,278 [JobControl] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-27 00:10:15,295 [JobControl] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.task.id is deprecated. Instead, use mapreduce.task.attempt.id
# 2023-01-27 00:10:15,354 [JobControl] WARN  org.apache.hadoop.mapreduce.JobResourceUploader - No job jar file set.  User classes may not be found. See Job or Job#setJar(String).
# 2023-01-27 00:10:15,371 [JobControl] INFO  org.apache.pig.builtin.PigStorage - Using PigTextInputFormat
# 2023-01-27 00:10:15,376 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2023-01-27 00:10:15,376 [JobControl] INFO  org.apache.pig.backend.hadoop.executionengine.util.MapRedUtil - Total input paths to process : 1
# 2023-01-27 00:10:15,393 [JobControl] INFO  org.apache.pig.backend.hadoop.executionengine.util.MapRedUtil - Total input paths (combined) to process : 1
# 2023-01-27 00:10:15,437 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - number of splits:1
# 2023-01-27 00:10:15,664 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - Submitting tokens for job: job_local1370833044_0001
# 2023-01-27 00:10:15,664 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - Executing with tokens: []
# 2023-01-27 00:10:15,816 [JobControl] INFO  org.apache.hadoop.mapreduce.Job - The url to track the job: http://localhost:8080/
# 2023-01-27 00:10:15,817 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - HadoopJobId: job_local1370833044_0001
# 2023-01-27 00:10:15,817 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - Processing aliases avgRatings,fiveStarMovies,ratings,ratingsByMovie
# 2023-01-27 00:10:15,817 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - detailed locations: M: ratings[2,10],ratings[-1,-1],avgRatings[8,13],ratingsByMovie[7,17] C: avgRatings[8,13],ratingsByMovie[7,17] R: avgRatings[8,13],fiveStarMovies[9,17]
# 2023-01-27 00:10:15,831 [Thread-5] INFO  org.apache.hadoop.mapred.LocalJobRunner - OutputCommitter set in config null
# 2023-01-27 00:10:15,833 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - 0% complete
# 2023-01-27 00:10:15,833 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - Running jobs are [job_local1370833044_0001]
# 2023-01-27 00:10:15,855 [Thread-5] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.reduce.tasks is deprecated. Instead, use mapreduce.job.reduces
# 2023-01-27 00:10:15,856 [Thread-5] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.job.tracker is deprecated. Instead, use mapreduce.jobtracker.address
# 2023-01-27 00:10:15,856 [Thread-5] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.job.reduce.markreset.buffer.percent is deprecated. Instead, use mapreduce.reduce.markreset.buffer.percent
# 2023-01-27 00:10:15,859 [Thread-5] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - File Output Committer Algorithm version is 2
# 2023-01-27 00:10:15,859 [Thread-5] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-01-27 00:10:15,859 [Thread-5] INFO  org.apache.hadoop.mapred.LocalJobRunner - OutputCommitter is org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.PigOutputCommitter
# 2023-01-27 00:10:15,915 [Thread-5] INFO  org.apache.hadoop.mapred.LocalJobRunner - Waiting for map tasks
# 2023-01-27 00:10:15,920 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.LocalJobRunner - Starting task: attempt_local1370833044_0001_m_000000_0
# 2023-01-27 00:10:15,959 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - File Output Committer Algorithm version is 2
# 2023-01-27 00:10:15,960 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-01-27 00:10:15,990 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.Task -  Using ResourceCalculatorProcessTree : [ ]
# 2023-01-27 00:10:15,997 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - Processing split: Number of splits :1
# Total Length = 1979173
# Input split[0]:
#    Length = 1979173
#    ClassName: org.apache.hadoop.mapreduce.lib.input.FileSplit
#    Locations:
#
# -----------------------
#
# 2023-01-27 00:10:16,006 [LocalJobRunner Map Task Executor #0] INFO  org.apache.pig.builtin.PigStorage - Using PigTextInputFormat
# 2023-01-27 00:10:16,010 [LocalJobRunner Map Task Executor #0] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.PigRecordReader - Current split being processed file:/content/data_pig/ml-100k/u.data:0+1979173
# 2023-01-27 00:10:16,051 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - (EQUATOR) 0 kvi 26214396(104857584)
# 2023-01-27 00:10:16,051 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - mapreduce.task.io.sort.mb: 100
# 2023-01-27 00:10:16,051 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - soft limit at 83886080
# 2023-01-27 00:10:16,051 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - bufstart = 0; bufvoid = 104857600
# 2023-01-27 00:10:16,051 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - kvstart = 26214396; length = 6553600
# 2023-01-27 00:10:16,056 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2023-01-27 00:10:16,066 [LocalJobRunner Map Task Executor #0] INFO  org.apache.pig.impl.util.SpillableMemoryManager - Selected heap (G1 Old Gen) of size 1048576000 to monitor. collectionUsageThreshold = 734003200, usageThreshold = 734003200
# 2023-01-27 00:10:16,069 [LocalJobRunner Map Task Executor #0] INFO  org.apache.pig.data.SchemaTupleBackend - Key [pig.schematuple] was not set... will not generate code.
# 2023-01-27 00:10:16,083 [LocalJobRunner Map Task Executor #0] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.PigGenericMapReduce$Map - Aliases being processed per job phase (AliasName[line,offset]): M: ratings[2,10],ratings[-1,-1],avgRatings[8,13],ratingsByMovie[7,17] C: avgRatings[8,13],ratingsByMovie[7,17] R: avgRatings[8,13],fiveStarMovies[9,17]
# 2023-01-27 00:10:17,216 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.LocalJobRunner -
# 2023-01-27 00:10:17,216 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - Starting flush of map output
# 2023-01-27 00:10:17,216 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - Spilling map output
# 2023-01-27 00:10:17,216 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - bufstart = 0; bufend = 1293890; bufvoid = 104857600
# 2023-01-27 00:10:17,216 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - kvstart = 26214396(104857584); kvend = 25814400(103257600); length = 399997/6553600
# 2023-01-27 00:10:17,380 [LocalJobRunner Map Task Executor #0] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.PigCombiner$Combine - Aliases being processed per job phase (AliasName[line,offset]): M: ratings[2,10],ratings[-1,-1],avgRatings[8,13],ratingsByMovie[7,17] C: avgRatings[8,13],ratingsByMovie[7,17] R: avgRatings[8,13],fiveStarMovies[9,17]
# 2023-01-27 00:10:17,593 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - Finished spill 0
# 2023-01-27 00:10:17,604 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.Task - Task:attempt_local1370833044_0001_m_000000_0 is done. And is in the process of committing
# 2023-01-27 00:10:17,606 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.LocalJobRunner - map
# 2023-01-27 00:10:17,606 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.Task - Task 'attempt_local1370833044_0001_m_000000_0' done.
# 2023-01-27 00:10:17,611 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.Task - Final Counters for attempt_local1370833044_0001_m_000000_0: Counters: 18
# 	File System Counters
# 		FILE: Number of bytes read=1979594
# 		FILE: Number of bytes written=663666
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=100000
# 		Map output records=100000
# 		Map output bytes=1293890
# 		Map output materialized bytes=27662
# 		Input split bytes=364
# 		Combine input records=100000
# 		Combine output records=1682
# 		Spilled Records=1682
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=29
# 		Total committed heap usage (bytes)=314572800
# 	File Input Format Counters
# 		Bytes Read=0
# 2023-01-27 00:10:17,611 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.LocalJobRunner - Finishing task: attempt_local1370833044_0001_m_000000_0
# 2023-01-27 00:10:17,612 [Thread-5] INFO  org.apache.hadoop.mapred.LocalJobRunner - map task executor complete.
# 2023-01-27 00:10:17,614 [Thread-5] INFO  org.apache.hadoop.mapred.LocalJobRunner - Waiting for reduce tasks
# 2023-01-27 00:10:17,615 [pool-4-thread-1] INFO  org.apache.hadoop.mapred.LocalJobRunner - Starting task: attempt_local1370833044_0001_r_000000_0
# 2023-01-27 00:10:17,632 [pool-4-thread-1] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - File Output Committer Algorithm version is 2
# 2023-01-27 00:10:17,632 [pool-4-thread-1] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-01-27 00:10:17,635 [pool-4-thread-1] INFO  org.apache.hadoop.mapred.Task -  Using ResourceCalculatorProcessTree : [ ]
# 2023-01-27 00:10:17,637 [pool-4-thread-1] INFO  org.apache.hadoop.mapred.ReduceTask - Using ShuffleConsumerPlugin: org.apache.hadoop.mapreduce.task.reduce.Shuffle@2a7f40b5
# 2023-01-27 00:10:17,638 [pool-4-thread-1] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-27 00:10:17,653 [pool-4-thread-1] INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl - MergerManager: memoryLimit=734003200, maxSingleShuffleLimit=183500800, mergeThreshold=484442144, ioSortFactor=10, memToMemMergeOutputsThreshold=10
# 2023-01-27 00:10:17,662 [EventFetcher for fetching Map Completion Events] INFO  org.apache.hadoop.mapreduce.task.reduce.EventFetcher - attempt_local1370833044_0001_r_000000_0 Thread started: EventFetcher for fetching Map Completion Events
# 2023-01-27 00:10:17,685 [localfetcher#1] INFO  org.apache.hadoop.mapreduce.task.reduce.LocalFetcher - localfetcher#1 about to shuffle output of map attempt_local1370833044_0001_m_000000_0 decomp: 27658 len: 27662 to MEMORY
# 2023-01-27 00:10:17,688 [localfetcher#1] INFO  org.apache.hadoop.mapreduce.task.reduce.InMemoryMapOutput - Read 27658 bytes from map-output for attempt_local1370833044_0001_m_000000_0
# 2023-01-27 00:10:17,689 [localfetcher#1] INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl - closeInMemoryFile -> map-output of size: 27658, inMemoryMapOutputs.size() -> 1, commitMemory -> 0, usedMemory ->27658
# 2023-01-27 00:10:17,695 [EventFetcher for fetching Map Completion Events] INFO  org.apache.hadoop.mapreduce.task.reduce.EventFetcher - EventFetcher is interrupted.. Returning
# 2023-01-27 00:10:17,697 [pool-4-thread-1] INFO  org.apache.hadoop.mapred.LocalJobRunner - 1 / 1 copied.
# 2023-01-27 00:10:17,697 [pool-4-thread-1] INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl - finalMerge called with 1 in-memory map-outputs and 0 on-disk map-outputs
# 2023-01-27 00:10:17,704 [pool-4-thread-1] INFO  org.apache.hadoop.mapred.Merger - Merging 1 sorted segments
# 2023-01-27 00:10:17,704 [pool-4-thread-1] INFO  org.apache.hadoop.mapred.Merger - Down to the last merge-pass, with 1 segments left of total size: 27650 bytes
# 2023-01-27 00:10:17,711 [pool-4-thread-1] INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl - Merged 1 segments, 27658 bytes to disk to satisfy reduce memory limit
# 2023-01-27 00:10:17,711 [pool-4-thread-1] INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl - Merging 1 files, 27662 bytes from disk
# 2023-01-27 00:10:17,712 [pool-4-thread-1] INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl - Merging 0 segments, 0 bytes from memory into reduce
# 2023-01-27 00:10:17,712 [pool-4-thread-1] INFO  org.apache.hadoop.mapred.Merger - Merging 1 sorted segments
# 2023-01-27 00:10:17,712 [pool-4-thread-1] INFO  org.apache.hadoop.mapred.Merger - Down to the last merge-pass, with 1 segments left of total size: 27650 bytes
# 2023-01-27 00:10:17,713 [pool-4-thread-1] INFO  org.apache.hadoop.mapred.LocalJobRunner - 1 / 1 copied.
# 2023-01-27 00:10:17,718 [pool-4-thread-1] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - File Output Committer Algorithm version is 2
# 2023-01-27 00:10:17,718 [pool-4-thread-1] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-01-27 00:10:17,720 [pool-4-thread-1] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.skip.on is deprecated. Instead, use mapreduce.job.skiprecords
# 2023-01-27 00:10:17,720 [pool-4-thread-1] INFO  org.apache.pig.impl.util.SpillableMemoryManager - Selected heap (G1 Old Gen) of size 1048576000 to monitor. collectionUsageThreshold = 734003200, usageThreshold = 734003200
# 2023-01-27 00:10:17,721 [pool-4-thread-1] WARN  org.apache.pig.data.SchemaTupleBackend - SchemaTupleBackend has already been initialized
# 2023-01-27 00:10:17,726 [pool-4-thread-1] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.PigMapReduce$Reduce - Aliases being processed per job phase (AliasName[line,offset]): M: ratings[2,10],ratings[-1,-1],avgRatings[8,13],ratingsByMovie[7,17] C: avgRatings[8,13],ratingsByMovie[7,17] R: avgRatings[8,13],fiveStarMovies[9,17]
# 2023-01-27 00:10:17,767 [pool-4-thread-1] INFO  org.apache.hadoop.mapred.Task - Task:attempt_local1370833044_0001_r_000000_0 is done. And is in the process of committing
# 2023-01-27 00:10:17,779 [pool-4-thread-1] INFO  org.apache.hadoop.mapred.LocalJobRunner - 1 / 1 copied.
# 2023-01-27 00:10:17,779 [pool-4-thread-1] INFO  org.apache.hadoop.mapred.Task - Task attempt_local1370833044_0001_r_000000_0 is allowed to commit now
# 2023-01-27 00:10:17,786 [pool-4-thread-1] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - Saved output of task 'attempt_local1370833044_0001_r_000000_0' to file:/tmp/temp1649418472/tmp69341176
# 2023-01-27 00:10:17,788 [pool-4-thread-1] INFO  org.apache.hadoop.mapred.LocalJobRunner - reduce > reduce
# 2023-01-27 00:10:17,788 [pool-4-thread-1] INFO  org.apache.hadoop.mapred.Task - Task 'attempt_local1370833044_0001_r_000000_0' done.
# 2023-01-27 00:10:17,789 [pool-4-thread-1] INFO  org.apache.hadoop.mapred.Task - Final Counters for attempt_local1370833044_0001_r_000000_0: Counters: 24
# 	File System Counters
# 		FILE: Number of bytes read=2034950
# 		FILE: Number of bytes written=693447
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=1682
# 		Reduce shuffle bytes=27662
# 		Reduce input records=1682
# 		Reduce output records=132
# 		Spilled Records=1682
# 		Shuffled Maps =1
# 		Failed Shuffles=0
# 		Merged Map outputs=1
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=314572800
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Output Format Counters
# 		Bytes Written=0
# 2023-01-27 00:10:17,791 [pool-4-thread-1] INFO  org.apache.hadoop.mapred.LocalJobRunner - Finishing task: attempt_local1370833044_0001_r_000000_0
# 2023-01-27 00:10:17,791 [Thread-5] INFO  org.apache.hadoop.mapred.LocalJobRunner - reduce task executor complete.
# 2023-01-27 00:10:17,834 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - 25% complete
# 2023-01-27 00:10:17,837 [main] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-27 00:10:17,848 [main] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-27 00:10:17,849 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.map.tasks is deprecated. Instead, use mapreduce.job.maps
# 2023-01-27 00:10:17,850 [main] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-27 00:10:17,895 [main] INFO  org.apache.pig.tools.pigstats.mapreduce.MRScriptState - Pig script settings are added to the job
# 2023-01-27 00:10:17,898 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler - mapred.job.reduce.markreset.buffer.percent is not set, set to default 0.3
# 2023-01-27 00:10:17,899 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler - Reduce phase detected, estimating # of required reducers.
# 2023-01-27 00:10:17,899 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler - Using reducer estimator: org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.InputSizeReducerEstimator
# 2023-01-27 00:10:17,901 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.InputSizeReducerEstimator - BytesPerReducer=1000000000 maxReducers=999 totalInputFileSize=238435
# 2023-01-27 00:10:17,901 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler - Setting Parallelism to 1
# 2023-01-27 00:10:17,903 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler - Setting up single store job
# 2023-01-27 00:10:17,934 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - 1 map-reduce job(s) waiting for submission.
# 2023-01-27 00:10:17,945 [JobControl] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-27 00:10:17,952 [JobControl] WARN  org.apache.hadoop.mapreduce.JobResourceUploader - No job jar file set.  User classes may not be found. See Job or Job#setJar(String).
# 2023-01-27 00:10:17,958 [JobControl] INFO  org.apache.pig.builtin.PigStorage - Using PigTextInputFormat
# 2023-01-27 00:10:17,960 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2023-01-27 00:10:17,960 [JobControl] INFO  org.apache.pig.backend.hadoop.executionengine.util.MapRedUtil - Total input paths to process : 1
# 2023-01-27 00:10:17,961 [JobControl] INFO  org.apache.pig.backend.hadoop.executionengine.util.MapRedUtil - Total input paths (combined) to process : 1
# 2023-01-27 00:10:17,970 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2023-01-27 00:10:17,970 [JobControl] INFO  org.apache.pig.backend.hadoop.executionengine.util.MapRedUtil - Total input paths to process : 1
# 2023-01-27 00:10:17,970 [JobControl] INFO  org.apache.pig.backend.hadoop.executionengine.util.MapRedUtil - Total input paths (combined) to process : 1
# 2023-01-27 00:10:17,974 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - number of splits:2
# 2023-01-27 00:10:17,994 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - Submitting tokens for job: job_local120840606_0002
# 2023-01-27 00:10:17,994 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - Executing with tokens: []
# 2023-01-27 00:10:18,100 [JobControl] INFO  org.apache.hadoop.mapreduce.Job - The url to track the job: http://localhost:8080/
# 2023-01-27 00:10:18,102 [Thread-14] INFO  org.apache.hadoop.mapred.LocalJobRunner - OutputCommitter set in config null
# 2023-01-27 00:10:18,118 [Thread-14] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.reduce.tasks is deprecated. Instead, use mapreduce.job.reduces
# 2023-01-27 00:10:18,118 [Thread-14] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.job.tracker is deprecated. Instead, use mapreduce.jobtracker.address
# 2023-01-27 00:10:18,118 [Thread-14] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.job.reduce.markreset.buffer.percent is deprecated. Instead, use mapreduce.reduce.markreset.buffer.percent
# 2023-01-27 00:10:18,118 [Thread-14] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - File Output Committer Algorithm version is 2
# 2023-01-27 00:10:18,119 [Thread-14] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-01-27 00:10:18,119 [Thread-14] INFO  org.apache.hadoop.mapred.LocalJobRunner - OutputCommitter is org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.PigOutputCommitter
# 2023-01-27 00:10:18,125 [Thread-14] INFO  org.apache.hadoop.mapred.LocalJobRunner - Waiting for map tasks
# 2023-01-27 00:10:18,125 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.LocalJobRunner - Starting task: attempt_local120840606_0002_m_000000_0
# 2023-01-27 00:10:18,137 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - File Output Committer Algorithm version is 2
# 2023-01-27 00:10:18,137 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-01-27 00:10:18,137 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.Task -  Using ResourceCalculatorProcessTree : [ ]
# 2023-01-27 00:10:18,139 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - Processing split: Number of splits :1
# Total Length = 236344
# Input split[0]:
#    Length = 236344
#    ClassName: org.apache.hadoop.mapreduce.lib.input.FileSplit
#    Locations:
#
# -----------------------
#
# 2023-01-27 00:10:18,143 [LocalJobRunner Map Task Executor #0] INFO  org.apache.pig.builtin.PigStorage - Using PigTextInputFormat
# 2023-01-27 00:10:18,143 [LocalJobRunner Map Task Executor #0] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.PigRecordReader - Current split being processed file:/content/data_pig/ml-100k/u.item:0+236344
# 2023-01-27 00:10:18,151 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - (EQUATOR) 0 kvi 26214396(104857584)
# 2023-01-27 00:10:18,151 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - mapreduce.task.io.sort.mb: 100
# 2023-01-27 00:10:18,151 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - soft limit at 83886080
# 2023-01-27 00:10:18,151 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - bufstart = 0; bufvoid = 104857600
# 2023-01-27 00:10:18,151 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - kvstart = 26214396; length = 6553600
# 2023-01-27 00:10:18,152 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2023-01-27 00:10:18,161 [LocalJobRunner Map Task Executor #0] INFO  org.apache.pig.impl.util.SpillableMemoryManager - Selected heap (G1 Old Gen) of size 1048576000 to monitor. collectionUsageThreshold = 734003200, usageThreshold = 734003200
# 2023-01-27 00:10:18,161 [LocalJobRunner Map Task Executor #0] WARN  org.apache.pig.data.SchemaTupleBackend - SchemaTupleBackend has already been initialized
# 2023-01-27 00:10:18,165 [LocalJobRunner Map Task Executor #0] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.PigGenericMapReduce$Map - Aliases being processed per job phase (AliasName[line,offset]): M: metadata[3,11],nameLookup[-1,-1],fiveStarsWithData[10,20],fiveStarsWithData[10,20] C:  R:
# 2023-01-27 00:10:18,280 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.LocalJobRunner -
# 2023-01-27 00:10:18,280 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - Starting flush of map output
# 2023-01-27 00:10:18,280 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - Spilling map output
# 2023-01-27 00:10:18,280 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - bufstart = 0; bufend = 68061; bufvoid = 104857600
# 2023-01-27 00:10:18,280 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - kvstart = 26214396(104857584); kvend = 26207672(104830688); length = 6725/6553600
# 2023-01-27 00:10:18,285 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - Finished spill 0
# 2023-01-27 00:10:18,287 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.Task - Task:attempt_local120840606_0002_m_000000_0 is done. And is in the process of committing
# 2023-01-27 00:10:18,288 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.LocalJobRunner - map
# 2023-01-27 00:10:18,288 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.Task - Task 'attempt_local120840606_0002_m_000000_0' done.
# 2023-01-27 00:10:18,289 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.Task - Final Counters for attempt_local120840606_0002_m_000000_0: Counters: 18
# 	File System Counters
# 		FILE: Number of bytes read=2272112
# 		FILE: Number of bytes written=1379062
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=1682
# 		Map output records=1682
# 		Map output bytes=68061
# 		Map output materialized bytes=71431
# 		Input split bytes=364
# 		Combine input records=0
# 		Spilled Records=1682
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=314572800
# 	MultiInputCounters
# 		Input records from _0_u.item=1682
# 	File Input Format Counters
# 		Bytes Read=0
# 2023-01-27 00:10:18,295 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.LocalJobRunner - Finishing task: attempt_local120840606_0002_m_000000_0
# 2023-01-27 00:10:18,295 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.LocalJobRunner - Starting task: attempt_local120840606_0002_m_000001_0
# 2023-01-27 00:10:18,300 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - File Output Committer Algorithm version is 2
# 2023-01-27 00:10:18,300 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-01-27 00:10:18,300 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.Task -  Using ResourceCalculatorProcessTree : [ ]
# 2023-01-27 00:10:18,302 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - Processing split: Number of splits :1
# Total Length = 2091
# Input split[0]:
#    Length = 2091
#    ClassName: org.apache.hadoop.mapreduce.lib.input.FileSplit
#    Locations:
#
# -----------------------
#
# 2023-01-27 00:10:18,306 [LocalJobRunner Map Task Executor #0] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.PigRecordReader - Current split being processed file:/tmp/temp1649418472/tmp69341176/part-r-00000:0+2091
# 2023-01-27 00:10:18,336 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - (EQUATOR) 0 kvi 26214396(104857584)
# 2023-01-27 00:10:18,336 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - mapreduce.task.io.sort.mb: 100
# 2023-01-27 00:10:18,336 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - soft limit at 83886080
# 2023-01-27 00:10:18,336 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - bufstart = 0; bufvoid = 104857600
# 2023-01-27 00:10:18,336 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - kvstart = 26214396; length = 6553600
# 2023-01-27 00:10:18,349 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2023-01-27 00:10:18,354 [LocalJobRunner Map Task Executor #0] INFO  org.apache.pig.impl.util.SpillableMemoryManager - Selected heap (G1 Old Gen) of size 1048576000 to monitor. collectionUsageThreshold = 734003200, usageThreshold = 734003200
# 2023-01-27 00:10:18,354 [LocalJobRunner Map Task Executor #0] WARN  org.apache.pig.data.SchemaTupleBackend - SchemaTupleBackend has already been initialized
# 2023-01-27 00:10:18,357 [LocalJobRunner Map Task Executor #0] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.PigGenericMapReduce$Map - Aliases being processed per job phase (AliasName[line,offset]): M: metadata[3,11],nameLookup[-1,-1],fiveStarsWithData[10,20],fiveStarsWithData[10,20] C:  R:
# 2023-01-27 00:10:18,364 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.LocalJobRunner -
# 2023-01-27 00:10:18,364 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - Starting flush of map output
# 2023-01-27 00:10:18,364 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - Spilling map output
# 2023-01-27 00:10:18,364 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - bufstart = 0; bufend = 2376; bufvoid = 104857600
# 2023-01-27 00:10:18,364 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - kvstart = 26214396(104857584); kvend = 26213872(104855488); length = 525/6553600
# 2023-01-27 00:10:18,366 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - Finished spill 0
# 2023-01-27 00:10:18,372 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.Task - Task:attempt_local120840606_0002_m_000001_0 is done. And is in the process of committing
# 2023-01-27 00:10:18,374 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.LocalJobRunner - map
# 2023-01-27 00:10:18,374 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.Task - Task 'attempt_local120840606_0002_m_000001_0' done.
# 2023-01-27 00:10:18,375 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.Task - Final Counters for attempt_local120840606_0002_m_000001_0: Counters: 18
# 	File System Counters
# 		FILE: Number of bytes read=2274998
# 		FILE: Number of bytes written=1381740
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=132
# 		Map output records=132
# 		Map output bytes=2376
# 		Map output materialized bytes=2646
# 		Input split bytes=376
# 		Combine input records=0
# 		Spilled Records=132
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=11
# 		Total committed heap usage (bytes)=314572800
# 	MultiInputCounters
# 		Input records from _1_tmp69341176=132
# 	File Input Format Counters
# 		Bytes Read=0
# 2023-01-27 00:10:18,375 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.LocalJobRunner - Finishing task: attempt_local120840606_0002_m_000001_0
# 2023-01-27 00:10:18,375 [Thread-14] INFO  org.apache.hadoop.mapred.LocalJobRunner - map task executor complete.
# 2023-01-27 00:10:18,376 [Thread-14] INFO  org.apache.hadoop.mapred.LocalJobRunner - Waiting for reduce tasks
# 2023-01-27 00:10:18,376 [pool-9-thread-1] INFO  org.apache.hadoop.mapred.LocalJobRunner - Starting task: attempt_local120840606_0002_r_000000_0
# 2023-01-27 00:10:18,387 [pool-9-thread-1] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - File Output Committer Algorithm version is 2
# 2023-01-27 00:10:18,387 [pool-9-thread-1] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-01-27 00:10:18,390 [pool-9-thread-1] INFO  org.apache.hadoop.mapred.Task -  Using ResourceCalculatorProcessTree : [ ]
# 2023-01-27 00:10:18,390 [pool-9-thread-1] INFO  org.apache.hadoop.mapred.ReduceTask - Using ShuffleConsumerPlugin: org.apache.hadoop.mapreduce.task.reduce.Shuffle@6d5a6ba9
# 2023-01-27 00:10:18,390 [pool-9-thread-1] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-27 00:10:18,394 [pool-9-thread-1] INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl - MergerManager: memoryLimit=734003200, maxSingleShuffleLimit=183500800, mergeThreshold=484442144, ioSortFactor=10, memToMemMergeOutputsThreshold=10
# 2023-01-27 00:10:18,395 [EventFetcher for fetching Map Completion Events] INFO  org.apache.hadoop.mapreduce.task.reduce.EventFetcher - attempt_local120840606_0002_r_000000_0 Thread started: EventFetcher for fetching Map Completion Events
# 2023-01-27 00:10:18,397 [localfetcher#2] INFO  org.apache.hadoop.mapreduce.task.reduce.LocalFetcher - localfetcher#2 about to shuffle output of map attempt_local120840606_0002_m_000000_0 decomp: 71427 len: 71431 to MEMORY
# 2023-01-27 00:10:18,397 [localfetcher#2] INFO  org.apache.hadoop.mapreduce.task.reduce.InMemoryMapOutput - Read 71427 bytes from map-output for attempt_local120840606_0002_m_000000_0
# 2023-01-27 00:10:18,398 [localfetcher#2] INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl - closeInMemoryFile -> map-output of size: 71427, inMemoryMapOutputs.size() -> 1, commitMemory -> 0, usedMemory ->71427
# 2023-01-27 00:10:18,401 [localfetcher#2] INFO  org.apache.hadoop.mapreduce.task.reduce.LocalFetcher - localfetcher#2 about to shuffle output of map attempt_local120840606_0002_m_000001_0 decomp: 2642 len: 2646 to MEMORY
# 2023-01-27 00:10:18,402 [localfetcher#2] INFO  org.apache.hadoop.mapreduce.task.reduce.InMemoryMapOutput - Read 2642 bytes from map-output for attempt_local120840606_0002_m_000001_0
# 2023-01-27 00:10:18,402 [localfetcher#2] INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl - closeInMemoryFile -> map-output of size: 2642, inMemoryMapOutputs.size() -> 2, commitMemory -> 71427, usedMemory ->74069
# 2023-01-27 00:10:18,406 [EventFetcher for fetching Map Completion Events] INFO  org.apache.hadoop.mapreduce.task.reduce.EventFetcher - EventFetcher is interrupted.. Returning
# 2023-01-27 00:10:18,407 [pool-9-thread-1] INFO  org.apache.hadoop.mapred.LocalJobRunner - 2 / 2 copied.
# 2023-01-27 00:10:18,407 [pool-9-thread-1] INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl - finalMerge called with 2 in-memory map-outputs and 0 on-disk map-outputs
# 2023-01-27 00:10:18,408 [pool-9-thread-1] INFO  org.apache.hadoop.mapred.Merger - Merging 2 sorted segments
# 2023-01-27 00:10:18,411 [pool-9-thread-1] INFO  org.apache.hadoop.mapred.Merger - Down to the last merge-pass, with 2 segments left of total size: 74053 bytes
# 2023-01-27 00:10:18,415 [pool-9-thread-1] INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl - Merged 2 segments, 74069 bytes to disk to satisfy reduce memory limit
# 2023-01-27 00:10:18,416 [pool-9-thread-1] INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl - Merging 1 files, 74071 bytes from disk
# 2023-01-27 00:10:18,416 [pool-9-thread-1] INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl - Merging 0 segments, 0 bytes from memory into reduce
# 2023-01-27 00:10:18,416 [pool-9-thread-1] INFO  org.apache.hadoop.mapred.Merger - Merging 1 sorted segments
# 2023-01-27 00:10:18,418 [pool-9-thread-1] INFO  org.apache.hadoop.mapred.Merger - Down to the last merge-pass, with 1 segments left of total size: 74059 bytes
# 2023-01-27 00:10:18,419 [pool-9-thread-1] INFO  org.apache.hadoop.mapred.LocalJobRunner - 2 / 2 copied.
# 2023-01-27 00:10:18,422 [pool-9-thread-1] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - File Output Committer Algorithm version is 2
# 2023-01-27 00:10:18,422 [pool-9-thread-1] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-01-27 00:10:18,424 [pool-9-thread-1] INFO  org.apache.pig.impl.util.SpillableMemoryManager - Selected heap (G1 Old Gen) of size 1048576000 to monitor. collectionUsageThreshold = 734003200, usageThreshold = 734003200
# 2023-01-27 00:10:18,424 [pool-9-thread-1] WARN  org.apache.pig.data.SchemaTupleBackend - SchemaTupleBackend has already been initialized
# 2023-01-27 00:10:18,426 [pool-9-thread-1] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.PigMapReduce$Reduce - Aliases being processed per job phase (AliasName[line,offset]): M: metadata[3,11],nameLookup[-1,-1],fiveStarsWithData[10,20],fiveStarsWithData[10,20] C:  R:
# 2023-01-27 00:10:18,444 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - HadoopJobId: job_local120840606_0002
# 2023-01-27 00:10:18,444 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - Processing aliases fiveStarsWithData,metadata,nameLookup
# 2023-01-27 00:10:18,444 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - detailed locations: M: metadata[3,11],nameLookup[-1,-1],fiveStarsWithData[10,20],fiveStarsWithData[10,20] C:  R:
# 2023-01-27 00:10:18,448 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - 37% complete
# 2023-01-27 00:10:18,448 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - Running jobs are [job_local120840606_0002]
# 2023-01-27 00:10:18,453 [pool-9-thread-1] INFO  org.apache.hadoop.mapred.Task - Task:attempt_local120840606_0002_r_000000_0 is done. And is in the process of committing
# 2023-01-27 00:10:18,457 [pool-9-thread-1] INFO  org.apache.hadoop.mapred.LocalJobRunner - 2 / 2 copied.
# 2023-01-27 00:10:18,458 [pool-9-thread-1] INFO  org.apache.hadoop.mapred.Task - Task attempt_local120840606_0002_r_000000_0 is allowed to commit now
# 2023-01-27 00:10:18,462 [pool-9-thread-1] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - Saved output of task 'attempt_local120840606_0002_r_000000_0' to file:/tmp/temp1649418472/tmp105037710
# 2023-01-27 00:10:18,469 [pool-9-thread-1] INFO  org.apache.hadoop.mapred.LocalJobRunner - reduce > reduce
# 2023-01-27 00:10:18,470 [pool-9-thread-1] INFO  org.apache.hadoop.mapred.Task - Task 'attempt_local120840606_0002_r_000000_0' done.
# 2023-01-27 00:10:18,471 [pool-9-thread-1] INFO  org.apache.hadoop.mapred.Task - Final Counters for attempt_local120840606_0002_r_000000_0: Counters: 24
# 	File System Counters
# 		FILE: Number of bytes read=2423210
# 		FILE: Number of bytes written=1462616
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=1682
# 		Reduce shuffle bytes=74077
# 		Reduce input records=1814
# 		Reduce output records=132
# 		Spilled Records=1814
# 		Shuffled Maps =2
# 		Failed Shuffles=0
# 		Merged Map outputs=2
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=314572800
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Output Format Counters
# 		Bytes Written=0
# 2023-01-27 00:10:18,472 [pool-9-thread-1] INFO  org.apache.hadoop.mapred.LocalJobRunner - Finishing task: attempt_local120840606_0002_r_000000_0
# 2023-01-27 00:10:18,473 [Thread-14] INFO  org.apache.hadoop.mapred.LocalJobRunner - reduce task executor complete.
# 2023-01-27 00:10:18,604 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - 50% complete
# 2023-01-27 00:10:18,606 [main] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-27 00:10:18,608 [main] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-27 00:10:18,611 [main] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-27 00:10:18,621 [main] INFO  org.apache.pig.tools.pigstats.mapreduce.MRScriptState - Pig script settings are added to the job
# 2023-01-27 00:10:18,621 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler - mapred.job.reduce.markreset.buffer.percent is not set, set to default 0.3
# 2023-01-27 00:10:18,622 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler - Reduce phase detected, estimating # of required reducers.
# 2023-01-27 00:10:18,622 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler - Using reducer estimator: org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.InputSizeReducerEstimator
# 2023-01-27 00:10:18,624 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.InputSizeReducerEstimator - BytesPerReducer=1000000000 maxReducers=999 totalInputFileSize=6741
# 2023-01-27 00:10:18,625 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler - Setting Parallelism to 1
# ...
# 2023-01-27 00:10:19,230 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - Processing split: Number of splits :1
# Total Length = 6741
# Input split[0]:
#    Length = 6741
#    ClassName: org.apache.hadoop.mapreduce.lib.input.FileSplit
#    Locations:
#
# -----------------------
#
# 2023-01-27 00:10:19,232 [LocalJobRunner Map Task Executor #0] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.PigRecordReader - Current split being processed file:/tmp/temp1649418472/tmp105037710/part-r-00000:0+6741
# 2023-01-27 00:10:19,258 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - (EQUATOR) 0 kvi 26214396(104857584)
# 2023-01-27 00:10:19,266 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - mapreduce.task.io.sort.mb: 100
# 2023-01-27 00:10:19,266 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - soft limit at 83886080
# 2023-01-27 00:10:19,266 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - bufstart = 0; bufvoid = 104857600
# 2023-01-27 00:10:19,266 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - kvstart = 26214396; length = 6553600
# 2023-01-27 00:10:19,272 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2023-01-27 00:10:19,274 [LocalJobRunner Map Task Executor #0] INFO  org.apache.pig.impl.util.SpillableMemoryManager - Selected heap (G1 Old Gen) of size 1048576000 to monitor. collectionUsageThreshold = 734003200, usageThreshold = 734003200
# 2023-01-27 00:10:19,274 [LocalJobRunner Map Task Executor #0] WARN  org.apache.pig.data.SchemaTupleBackend - SchemaTupleBackend has already been initialized
# 2023-01-27 00:10:19,275 [LocalJobRunner Map Task Executor #0] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.PigGenericMapReduce$Map - Aliases being processed per job phase (AliasName[line,offset]): M: oldestFiveStarMovies[11,23] C:  R:
# 2023-01-27 00:10:19,293 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.LocalJobRunner -
# 2023-01-27 00:10:19,294 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - Starting flush of map output
# 2023-01-27 00:10:19,294 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - Spilling map output
# 2023-01-27 00:10:19,294 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - bufstart = 0; bufend = 7269; bufvoid = 104857600
# 2023-01-27 00:10:19,294 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - kvstart = 26214396(104857584); kvend = 26213872(104855488); length = 525/6553600
# 2023-01-27 00:10:19,296 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - Finished spill 0
# 2023-01-27 00:10:19,297 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.Task - Task:attempt_local1029384707_0004_m_000000_0 is done. And is in the process of committing
# 2023-01-27 00:10:19,298 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.LocalJobRunner - map
# 2023-01-27 00:10:19,298 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.Task - Task 'attempt_local1029384707_0004_m_000000_0' done.
# 2023-01-27 00:10:19,298 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.Task - Final Counters for attempt_local1029384707_0004_m_000000_0: Counters: 17
# 	File System Counters
# 		FILE: Number of bytes read=2442538
# 		FILE: Number of bytes written=2709350
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=132
# 		Map output records=132
# 		Map output bytes=7269
# 		Map output materialized bytes=7539
# 		Input split bytes=377
# 		Combine input records=0
# 		Spilled Records=132
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=13
# 		Total committed heap usage (bytes)=316669952
# 	File Input Format Counters
# 		Bytes Read=0
# 2023-01-27 00:10:19,299 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.LocalJobRunner - Finishing task: attempt_local1029384707_0004_m_000000_0
# 2023-01-27 00:10:19,300 [Thread-29] INFO  org.apache.hadoop.mapred.LocalJobRunner - map task executor complete.
# 2023-01-27 00:10:19,317 [Thread-29] INFO  org.apache.hadoop.mapred.LocalJobRunner - Waiting for reduce tasks
# 2023-01-27 00:10:19,319 [pool-15-thread-1] INFO  org.apache.hadoop.mapred.LocalJobRunner - Starting task: attempt_local1029384707_0004_r_000000_0
# 2023-01-27 00:10:19,334 [pool-15-thread-1] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - File Output Committer Algorithm version is 2
# 2023-01-27 00:10:19,334 [pool-15-thread-1] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-01-27 00:10:19,335 [pool-15-thread-1] INFO  org.apache.hadoop.mapred.Task -  Using ResourceCalculatorProcessTree : [ ]
# 2023-01-27 00:10:19,335 [pool-15-thread-1] INFO  org.apache.hadoop.mapred.ReduceTask - Using ShuffleConsumerPlugin: org.apache.hadoop.mapreduce.task.reduce.Shuffle@198be529
# 2023-01-27 00:10:19,336 [pool-15-thread-1] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-27 00:10:19,337 [pool-15-thread-1] INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl - MergerManager: memoryLimit=734003200, maxSingleShuffleLimit=183500800, mergeThreshold=484442144, ioSortFactor=10, memToMemMergeOutputsThreshold=10
# 2023-01-27 00:10:19,341 [EventFetcher for fetching Map Completion Events] INFO  org.apache.hadoop.mapreduce.task.reduce.EventFetcher - attempt_local1029384707_0004_r_000000_0 Thread started: EventFetcher for fetching Map Completion Events
# 2023-01-27 00:10:19,342 [localfetcher#4] INFO  org.apache.hadoop.mapreduce.task.reduce.LocalFetcher - localfetcher#4 about to shuffle output of map attempt_local1029384707_0004_m_000000_0 decomp: 7535 len: 7539 to MEMORY
# 2023-01-27 00:10:19,342 [localfetcher#4] INFO  org.apache.hadoop.mapreduce.task.reduce.InMemoryMapOutput - Read 7535 bytes from map-output for attempt_local1029384707_0004_m_000000_0
# 2023-01-27 00:10:19,342 [localfetcher#4] INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl - closeInMemoryFile -> map-output of size: 7535, inMemoryMapOutputs.size() -> 1, commitMemory -> 0, usedMemory ->7535
# 2023-01-27 00:10:19,343 [EventFetcher for fetching Map Completion Events] INFO  org.apache.hadoop.mapreduce.task.reduce.EventFetcher - EventFetcher is interrupted.. Returning
# 2023-01-27 00:10:19,343 [pool-15-thread-1] INFO  org.apache.hadoop.mapred.LocalJobRunner - 1 / 1 copied.
# 2023-01-27 00:10:19,343 [pool-15-thread-1] INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl - finalMerge called with 1 in-memory map-outputs and 0 on-disk map-outputs
# 2023-01-27 00:10:19,344 [pool-15-thread-1] INFO  org.apache.hadoop.mapred.Merger - Merging 1 sorted segments
# 2023-01-27 00:10:19,344 [pool-15-thread-1] INFO  org.apache.hadoop.mapred.Merger - Down to the last merge-pass, with 1 segments left of total size: 7523 bytes
# 2023-01-27 00:10:19,345 [pool-15-thread-1] INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl - Merged 1 segments, 7535 bytes to disk to satisfy reduce memory limit
# 2023-01-27 00:10:19,345 [pool-15-thread-1] INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl - Merging 1 files, 7539 bytes from disk
# 2023-01-27 00:10:19,345 [pool-15-thread-1] INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl - Merging 0 segments, 0 bytes from memory into reduce
# 2023-01-27 00:10:19,345 [pool-15-thread-1] INFO  org.apache.hadoop.mapred.Merger - Merging 1 sorted segments
# 2023-01-27 00:10:19,346 [pool-15-thread-1] INFO  org.apache.hadoop.mapred.Merger - Down to the last merge-pass, with 1 segments left of total size: 7523 bytes
# 2023-01-27 00:10:19,346 [pool-15-thread-1] INFO  org.apache.hadoop.mapred.LocalJobRunner - 1 / 1 copied.
# 2023-01-27 00:10:19,348 [pool-15-thread-1] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - File Output Committer Algorithm version is 2
# 2023-01-27 00:10:19,348 [pool-15-thread-1] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-01-27 00:10:19,349 [pool-15-thread-1] INFO  org.apache.pig.impl.util.SpillableMemoryManager - Selected heap (G1 Old Gen) of size 1048576000 to monitor. collectionUsageThreshold = 734003200, usageThreshold = 734003200
# 2023-01-27 00:10:19,349 [pool-15-thread-1] WARN  org.apache.pig.data.SchemaTupleBackend - SchemaTupleBackend has already been initialized
# 2023-01-27 00:10:19,351 [pool-15-thread-1] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.PigMapReduce$Reduce - Aliases being processed per job phase (AliasName[line,offset]): M: oldestFiveStarMovies[11,23] C:  R:
# 2023-01-27 00:10:19,353 [pool-15-thread-1] INFO  org.apache.hadoop.mapred.Task - Task:attempt_local1029384707_0004_r_000000_0 is done. And is in the process of committing
# 2023-01-27 00:10:19,355 [pool-15-thread-1] INFO  org.apache.hadoop.mapred.LocalJobRunner - 1 / 1 copied.
# 2023-01-27 00:10:19,355 [pool-15-thread-1] INFO  org.apache.hadoop.mapred.Task - Task attempt_local1029384707_0004_r_000000_0 is allowed to commit now
# 2023-01-27 00:10:19,358 [pool-15-thread-1] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - Saved output of task 'attempt_local1029384707_0004_r_000000_0' to file:/tmp/temp1649418472/tmp-660352736
# 2023-01-27 00:10:19,359 [pool-15-thread-1] INFO  org.apache.hadoop.mapred.LocalJobRunner - reduce > reduce
# 2023-01-27 00:10:19,359 [pool-15-thread-1] INFO  org.apache.hadoop.mapred.Task - Task 'attempt_local1029384707_0004_r_000000_0' done.
# 2023-01-27 00:10:19,359 [pool-15-thread-1] INFO  org.apache.hadoop.mapred.Task - Final Counters for attempt_local1029384707_0004_r_000000_0: Counters: 24
# 	File System Counters
# 		FILE: Number of bytes read=2457648
# 		FILE: Number of bytes written=2723694
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=82
# 		Reduce shuffle bytes=7539
# 		Reduce input records=132
# 		Reduce output records=132
# 		Spilled Records=132
# 		Shuffled Maps =1
# 		Failed Shuffles=0
# 		Merged Map outputs=1
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=316669952
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Output Format Counters
# 		Bytes Written=0
# 2023-01-27 00:10:19,359 [pool-15-thread-1] INFO  org.apache.hadoop.mapred.LocalJobRunner - Finishing task: attempt_local1029384707_0004_r_000000_0
# 2023-01-27 00:10:19,359 [Thread-29] INFO  org.apache.hadoop.mapred.LocalJobRunner - reduce task executor complete.
# 2023-01-27 00:10:19,501 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - HadoopJobId: job_local1029384707_0004
# 2023-01-27 00:10:19,501 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - Processing aliases oldestFiveStarMovies
# 2023-01-27 00:10:19,501 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - detailed locations: M: oldestFiveStarMovies[11,23] C:  R:
# 2023-01-27 00:10:19,505 [main] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-27 00:10:19,507 [main] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-27 00:10:19,509 [main] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-27 00:10:19,528 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - 100% complete
# 2023-01-27 00:10:19,535 [main] INFO  org.apache.pig.tools.pigstats.mapreduce.SimplePigStats - Script Statistics:
#
# HadoopVersion	PigVersion	UserId	StartedAt	FinishedAt	Features
# 3.3.4	0.17.0	root	2023-01-27 00:10:15	2023-01-27 00:10:19	HASH_JOIN,GROUP_BY,ORDER_BY,FILTER
#
# Success!
#
# Job Stats (time in seconds):
# JobId	Maps	Reduces	MaxMapTime	MinMapTime	AvgMapTime	MedianMapTime	MaxReduceTime	MinReduceTime	AvgReduceTime	MedianReducetime	Alias	Feature	Outputs
# job_local1029384707_0004	1	1	n/a	n/a	n/a	n/a	n/a	n/a	n/a	n/a	oldestFiveStarMovies	ORDER_BY	file:/tmp/temp1649418472/tmp-660352736,
# job_local120840606_0002	2	1	n/a	n/a	n/a	n/a	n/a	n/a	n/a	n/a	fiveStarsWithData,metadata,nameLookup	HASH_JOIN
# job_local1370833044_0001	1	1	n/a	n/a	n/a	n/a	n/a	n/a	n/a	n/a	avgRatings,fiveStarMovies,ratings,ratingsByMovie	GROUP_BY,COMBINER
# job_local1409093449_0003	1	1	n/a	n/a	n/a	n/a	n/a	n/a	n/a	n/a	oldestFiveStarMovies	SAMPLER
#
# Input(s):
# Successfully read 100000 records from: "file:///content/data_pig/ml-100k/u.data"
# Successfully read 1682 records from: "file:///content/data_pig/ml-100k/u.item"
#
# Output(s):
# Successfully stored 132 records in: "file:/tmp/temp1649418472/tmp-660352736"
#
# Counters:
# Total records written : 132
# Total bytes written : 0
# Spillable Memory Manager spill count : 0
# Total bags proactively spilled: 0
# Total records proactively spilled: 0
#
# Job DAG:
# job_local1370833044_0001	->	job_local120840606_0002,
# job_local120840606_0002	->	job_local1409093449_0003,
# job_local1409093449_0003	->	job_local1029384707_0004,
# job_local1029384707_0004
#
#
# 2023-01-27 00:10:19,538 [main] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-27 00:10:19,541 [main] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-27 00:10:19,542 [main] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-27 00:10:19,553 [main] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-27 00:10:19,557 [main] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-27 00:10:19,558 [main] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-27 00:10:19,562 [main] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-27 00:10:19,563 [main] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-27 00:10:19,565 [main] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-27 00:10:19,569 [main] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-27 00:10:19,570 [main] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-27 00:10:19,571 [main] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-27 00:10:19,574 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - Success!
# 2023-01-27 00:10:19,579 [main] WARN  org.apache.pig.data.SchemaTupleBackend - SchemaTupleBackend has already been initialized
# 2023-01-27 00:10:19,581 [main] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2023-01-27 00:10:19,581 [main] INFO  org.apache.pig.backend.hadoop.executionengine.util.MapRedUtil - Total input paths to process : 1
# 2023-01-27 00:10:19,619 [main] INFO  org.apache.pig.Main - Pig script completed in 6 seconds and 207 milliseconds (6207 ms)

# %% [markdown]
# In the file we will see all rows order by timestamp and rating.

# %%
# !head fiveStarMovies.txt
# Out:
# (493,4.15,493,Thin Man, The (1934),-1136073600)
# (604,4.012345679012346,604,It Happened One Night (1934),-1136073600)
# (615,4.0508474576271185,615,39 Steps, The (1935),-1104537600)
# (1203,4.0476190476190474,1203,Top Hat (1935),-1104537600)
# (613,4.037037037037037,613,My Man Godfrey (1936),-1073001600)
# (633,4.057971014492754,633,Christmas Carol, A (1938),-1009843200)
# (136,4.123809523809523,136,Mr. Smith Goes to Washington (1939),-978307200)
# (1122,5.0,1122,They Made Me a Criminal (1939),-978307200)
# (132,4.0772357723577235,132,Wizard of Oz, The (1939),-978307200)
# (524,4.021739130434782,524,Great Dictator, The (1940),-946771200)

# %% [markdown]
# ---
#
# #### 8.2 - Find most rated bad movies ⭐

# %%
# %%writefile BadPopularMovies.pig
#
# ratings = LOAD 'file:///content/data_pig/ml-100k/u.data'
#   AS (userID:int, movieID:int, rating:int, ratingTime:int);
# metadata = LOAD 'file:///content/data_pig/ml-100k/u.item' USING PigStorage('|')
# 	AS (movieID:int, movieTitle:chararray, releaseDate:chararray, videoRealese:chararray, imdblink:chararray);
#
# nameLookup = FOREACH metadata GENERATE movieID, movieTitle;
#
# groupedRating = GROUP ratings by movieID;
#
# avgRatings = FOREACH groupedRating GENERATE group as movieID, AVG(ratings.rating) as avgRating, COUNT(ratings.rating) AS numRatings;
#
# badMovies = FILTER avgRatings BY avgRating < 2.0;
#
# namedBadMovies = JOIN badMovies BY movieID, nameLookup BY movieID;
#
# results = FOREACH namedBadMovies GENERATE nameLookup::movieTitle as movieName,
#           badMovies::avgRating as avgRating, badMovies::numRatings as numRatings;
#
# finalResults = ORDER results BY numRatings DESC;
#
# DUMP finalResults;
# Out:
# Overwriting BadPopularMovies.pig

# %% [markdown]
# Run script and save results in a file .txt:
#
# `!pig -x local BadPopularMovies.pig > BadPopularMovies.txt`

# %%
# !pig -x local BadPopularMovies.pig > BadPopularMovies.txt
# Out:
# 2023-01-27 00:12:31,042 INFO pig.ExecTypeProvider: Trying ExecType : LOCAL
# 2023-01-27 00:12:31,043 INFO pig.ExecTypeProvider: Picked LOCAL as the ExecType
# 2023-01-27 00:12:31,104 [main] INFO  org.apache.pig.Main - Apache Pig version 0.17.0 (r1797386) compiled Jun 02 2017, 15:41:58
# 2023-01-27 00:12:31,104 [main] INFO  org.apache.pig.Main - Logging error messages to: /content/pig_1674778351101.log
# 2023-01-27 00:12:31,121 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - user.name is deprecated. Instead, use mapreduce.job.user.name
# 2023-01-27 00:12:31,300 [main] INFO  org.apache.pig.impl.util.Utils - Default bootup file /root/.pigbootup not found
# 2023-01-27 00:12:31,386 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.job.tracker is deprecated. Instead, use mapreduce.jobtracker.address
# 2023-01-27 00:12:31,388 [main] INFO  org.apache.pig.backend.hadoop.executionengine.HExecutionEngine - Connecting to hadoop file system at: file:///
# 2023-01-27 00:12:31,410 [main] INFO  org.apache.pig.PigServer - Pig Script ID for the session: PIG-BadPopularMovies.pig-89ba9769-42fa-47c8-b37b-89c066ea41fe
# 2023-01-27 00:12:31,410 [main] WARN  org.apache.pig.PigServer - ATS is disabled since yarn.timeline-service.enabled set to false
# 2023-01-27 00:12:32,025 [main] INFO  org.apache.pig.impl.util.SpillableMemoryManager - Selected heap (G1 Old Gen) of size 1048576000 to monitor. collectionUsageThreshold = 734003200, usageThreshold = 734003200
# 2023-01-27 00:12:32,035 [main] INFO  org.apache.pig.tools.pigstats.ScriptState - Pig features used in the script: HASH_JOIN,GROUP_BY,ORDER_BY,FILTER
# 2023-01-27 00:12:32,091 [main] INFO  org.apache.pig.newplan.logical.optimizer.LogicalPlanOptimizer - {RULES_ENABLED=[AddForEach, ColumnMapKeyPrune, ConstantCalculator, GroupByConstParallelSetter, LimitOptimizer, LoadTypeCastInserter, MergeFilter, MergeForEach, NestedLimitOptimizer, PartitionFilterOptimizer, PredicatePushdownOptimizer, PushDownForEachFlatten, PushUpFilter, SplitFilter, StreamTypeCastInserter]}
# 2023-01-27 00:12:32,115 [main] INFO  org.apache.pig.newplan.logical.rules.ColumnPruneVisitor - Columns pruned for metadata: $2, $3, $4
# 2023-01-27 00:12:32,211 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MRCompiler - File concatenation threshold: 100 optimistic? false
# 2023-01-27 00:12:32,236 [main] INFO  org.apache.pig.backend.hadoop.executionengine.util.CombinerOptimizerUtil - Choosing to move algebraic foreach to combiner
# 2023-01-27 00:12:32,259 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.SecondaryKeyOptimizerMR - Using Secondary Key Optimization for MapReduce node scope-71
# 2023-01-27 00:12:32,264 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MRCompiler$LastInputStreamingOptimizer - Rewrite: POPackage->POForEach to POPackage(JoinPackager)
# 2023-01-27 00:12:32,270 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MultiQueryOptimizer - MR plan size before optimization: 4
# 2023-01-27 00:12:32,270 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MultiQueryOptimizer - MR plan size after optimization: 4
# 2023-01-27 00:12:32,373 [main] INFO  org.apache.hadoop.metrics2.impl.MetricsConfig - Loaded properties from hadoop-metrics2.properties
# 2023-01-27 00:12:32,478 [main] INFO  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - Scheduled Metric snapshot period at 10 second(s).
# 2023-01-27 00:12:32,478 [main] INFO  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system started
# 2023-01-27 00:12:32,507 [main] INFO  org.apache.pig.tools.pigstats.mapreduce.MRScriptState - Pig script settings are added to the job
# 2023-01-27 00:12:32,536 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.job.reduce.markreset.buffer.percent is deprecated. Instead, use mapreduce.reduce.markreset.buffer.percent
# 2023-01-27 00:12:32,541 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler - mapred.job.reduce.markreset.buffer.percent is not set, set to default 0.3
# 2023-01-27 00:12:32,543 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.output.compress is deprecated. Instead, use mapreduce.output.fileoutputformat.compress
# 2023-01-27 00:12:32,547 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler - Reduce phase detected, estimating # of required reducers.
# 2023-01-27 00:12:32,552 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler - Using reducer estimator: org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.InputSizeReducerEstimator
# 2023-01-27 00:12:32,558 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.InputSizeReducerEstimator - BytesPerReducer=1000000000 maxReducers=999 totalInputFileSize=1979173
# 2023-01-27 00:12:32,558 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler - Setting Parallelism to 1
# 2023-01-27 00:12:32,558 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.reduce.tasks is deprecated. Instead, use mapreduce.job.reduces
# 2023-01-27 00:12:32,568 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler - Setting up single store job
# 2023-01-27 00:12:32,575 [main] INFO  org.apache.pig.data.SchemaTupleFrontend - Key [pig.schematuple] is false, will not generate code.
# 2023-01-27 00:12:32,575 [main] INFO  org.apache.pig.data.SchemaTupleFrontend - Starting process to move generated code to distributed cacche
# 2023-01-27 00:12:32,576 [main] INFO  org.apache.pig.data.SchemaTupleFrontend - Distributed cache not supported or needed in local mode. Setting key [pig.schematuple.local.dir] with code temp directory: /tmp/1674778352575-0
# 2023-01-27 00:12:32,650 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - 1 map-reduce job(s) waiting for submission.
# 2023-01-27 00:12:32,659 [JobControl] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-27 00:12:32,677 [JobControl] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.task.id is deprecated. Instead, use mapreduce.task.attempt.id
# 2023-01-27 00:12:32,711 [JobControl] WARN  org.apache.hadoop.mapreduce.JobResourceUploader - No job jar file set.  User classes may not be found. See Job or Job#setJar(String).
# 2023-01-27 00:12:32,726 [JobControl] INFO  org.apache.pig.builtin.PigStorage - Using PigTextInputFormat
# 2023-01-27 00:12:32,731 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2023-01-27 00:12:32,731 [JobControl] INFO  org.apache.pig.backend.hadoop.executionengine.util.MapRedUtil - Total input paths to process : 1
# 2023-01-27 00:12:32,746 [JobControl] INFO  org.apache.pig.backend.hadoop.executionengine.util.MapRedUtil - Total input paths (combined) to process : 1
# 2023-01-27 00:12:32,779 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - number of splits:1
# 2023-01-27 00:12:33,002 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - Submitting tokens for job: job_local598888941_0001
# 2023-01-27 00:12:33,002 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - Executing with tokens: []
# 2023-01-27 00:12:33,172 [JobControl] INFO  org.apache.hadoop.mapreduce.Job - The url to track the job: http://localhost:8080/
# 2023-01-27 00:12:33,174 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - HadoopJobId: job_local598888941_0001
# 2023-01-27 00:12:33,175 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - Processing aliases avgRatings,badMovies,groupedRating,ratings
# 2023-01-27 00:12:33,175 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - detailed locations: M: ratings[2,10],ratings[-1,-1],avgRatings[10,13],groupedRating[8,16] C: avgRatings[10,13],groupedRating[8,16] R: avgRatings[10,13],badMovies[12,12]
# 2023-01-27 00:12:33,181 [Thread-5] INFO  org.apache.hadoop.mapred.LocalJobRunner - OutputCommitter set in config null
# 2023-01-27 00:12:33,194 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - 0% complete
# 2023-01-27 00:12:33,195 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - Running jobs are [job_local598888941_0001]
# 2023-01-27 00:12:33,214 [Thread-5] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.reduce.tasks is deprecated. Instead, use mapreduce.job.reduces
# 2023-01-27 00:12:33,214 [Thread-5] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.job.tracker is deprecated. Instead, use mapreduce.jobtracker.address
# 2023-01-27 00:12:33,214 [Thread-5] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.job.reduce.markreset.buffer.percent is deprecated. Instead, use mapreduce.reduce.markreset.buffer.percent
# 2023-01-27 00:12:33,222 [Thread-5] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - File Output Committer Algorithm version is 2
# 2023-01-27 00:12:33,222 [Thread-5] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-01-27 00:12:33,222 [Thread-5] INFO  org.apache.hadoop.mapred.LocalJobRunner - OutputCommitter is org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.PigOutputCommitter
# 2023-01-27 00:12:33,275 [Thread-5] INFO  org.apache.hadoop.mapred.LocalJobRunner - Waiting for map tasks
# 2023-01-27 00:12:33,278 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.LocalJobRunner - Starting task: attempt_local598888941_0001_m_000000_0
# 2023-01-27 00:12:33,317 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - File Output Committer Algorithm version is 2
# 2023-01-27 00:12:33,317 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-01-27 00:12:33,352 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.Task -  Using ResourceCalculatorProcessTree : [ ]
# 2023-01-27 00:12:33,364 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - Processing split: Number of splits :1
# Total Length = 1979173
# Input split[0]:
#    Length = 1979173
#    ClassName: org.apache.hadoop.mapreduce.lib.input.FileSplit
#    Locations:
#
# -----------------------
#
# 2023-01-27 00:12:33,373 [LocalJobRunner Map Task Executor #0] INFO  org.apache.pig.builtin.PigStorage - Using PigTextInputFormat
# 2023-01-27 00:12:33,376 [LocalJobRunner Map Task Executor #0] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.PigRecordReader - Current split being processed file:/content/data_pig/ml-100k/u.data:0+1979173
# 2023-01-27 00:12:33,445 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - (EQUATOR) 0 kvi 26214396(104857584)
# 2023-01-27 00:12:33,445 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - mapreduce.task.io.sort.mb: 100
# 2023-01-27 00:12:33,445 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - soft limit at 83886080
# 2023-01-27 00:12:33,445 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - bufstart = 0; bufvoid = 104857600
# 2023-01-27 00:12:33,445 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - kvstart = 26214396; length = 6553600
# 2023-01-27 00:12:33,462 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2023-01-27 00:12:33,473 [LocalJobRunner Map Task Executor #0] INFO  org.apache.pig.impl.util.SpillableMemoryManager - Selected heap (G1 Old Gen) of size 1048576000 to monitor. collectionUsageThreshold = 734003200, usageThreshold = 734003200
# 2023-01-27 00:12:33,476 [LocalJobRunner Map Task Executor #0] INFO  org.apache.pig.data.SchemaTupleBackend - Key [pig.schematuple] was not set... will not generate code.
# 2023-01-27 00:12:33,512 [LocalJobRunner Map Task Executor #0] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.PigGenericMapReduce$Map - Aliases being processed per job phase (AliasName[line,offset]): M: ratings[2,10],ratings[-1,-1],avgRatings[10,13],groupedRating[8,16] C: avgRatings[10,13],groupedRating[8,16] R: avgRatings[10,13],badMovies[12,12]
# 2023-01-27 00:12:34,758 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.LocalJobRunner -
# 2023-01-27 00:12:34,758 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - Starting flush of map output
# 2023-01-27 00:12:34,758 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - Spilling map output
# 2023-01-27 00:12:34,758 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - bufstart = 0; bufend = 1493890; bufvoid = 104857600
# 2023-01-27 00:12:34,758 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - kvstart = 26214396(104857584); kvend = 25814400(103257600); length = 399997/6553600
# 2023-01-27 00:12:34,952 [LocalJobRunner Map Task Executor #0] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.PigCombiner$Combine - Aliases being processed per job phase (AliasName[line,offset]): M: ratings[2,10],ratings[-1,-1],avgRatings[10,13],groupedRating[8,16] C: avgRatings[10,13],groupedRating[8,16] R: avgRatings[10,13],badMovies[12,12]
# 2023-01-27 00:12:35,248 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - Finished spill 0
# 2023-01-27 00:12:35,269 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.Task - Task:attempt_local598888941_0001_m_000000_0 is done. And is in the process of committing
# 2023-01-27 00:12:35,275 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.LocalJobRunner - map
# 2023-01-27 00:12:35,275 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.Task - Task 'attempt_local598888941_0001_m_000000_0' done.
# 2023-01-27 00:12:35,281 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.Task - Final Counters for attempt_local598888941_0001_m_000000_0: Counters: 18
# 	File System Counters
# 		FILE: Number of bytes read=1979594
# 		FILE: Number of bytes written=667966
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=100000
# 		Map output records=100000
# 		Map output bytes=1493890
# 		Map output materialized bytes=32820
# 		Input split bytes=364
# 		Combine input records=100000
# 		Combine output records=1682
# 		Spilled Records=1682
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=63
# 		Total committed heap usage (bytes)=287309824
# 	File Input Format Counters
# 		Bytes Read=0
# 2023-01-27 00:12:35,281 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.LocalJobRunner - Finishing task: attempt_local598888941_0001_m_000000_0
# 2023-01-27 00:12:35,282 [Thread-5] INFO  org.apache.hadoop.mapred.LocalJobRunner - map task executor complete.
# 2023-01-27 00:12:35,286 [Thread-5] INFO  org.apache.hadoop.mapred.LocalJobRunner - Waiting for reduce tasks
# 2023-01-27 00:12:35,287 [pool-4-thread-1] INFO  org.apache.hadoop.mapred.LocalJobRunner - Starting task: attempt_local598888941_0001_r_000000_0
# 2023-01-27 00:12:35,309 [pool-4-thread-1] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - File Output Committer Algorithm version is 2
# 2023-01-27 00:12:35,309 [pool-4-thread-1] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-01-27 00:12:35,312 [pool-4-thread-1] INFO  org.apache.hadoop.mapred.Task -  Using ResourceCalculatorProcessTree : [ ]
# 2023-01-27 00:12:35,315 [pool-4-thread-1] INFO  org.apache.hadoop.mapred.ReduceTask - Using ShuffleConsumerPlugin: org.apache.hadoop.mapreduce.task.reduce.Shuffle@56dacf48
# 2023-01-27 00:12:35,316 [pool-4-thread-1] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-27 00:12:35,334 [pool-4-thread-1] INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl - MergerManager: memoryLimit=734003200, maxSingleShuffleLimit=183500800, mergeThreshold=484442144, ioSortFactor=10, memToMemMergeOutputsThreshold=10
# 2023-01-27 00:12:35,340 [EventFetcher for fetching Map Completion Events] INFO  org.apache.hadoop.mapreduce.task.reduce.EventFetcher - attempt_local598888941_0001_r_000000_0 Thread started: EventFetcher for fetching Map Completion Events
# 2023-01-27 00:12:35,376 [localfetcher#1] INFO  org.apache.hadoop.mapreduce.task.reduce.LocalFetcher - localfetcher#1 about to shuffle output of map attempt_local598888941_0001_m_000000_0 decomp: 32816 len: 32820 to MEMORY
# 2023-01-27 00:12:35,380 [localfetcher#1] INFO  org.apache.hadoop.mapreduce.task.reduce.InMemoryMapOutput - Read 32816 bytes from map-output for attempt_local598888941_0001_m_000000_0
# 2023-01-27 00:12:35,381 [localfetcher#1] INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl - closeInMemoryFile -> map-output of size: 32816, inMemoryMapOutputs.size() -> 1, commitMemory -> 0, usedMemory ->32816
# 2023-01-27 00:12:35,385 [EventFetcher for fetching Map Completion Events] INFO  org.apache.hadoop.mapreduce.task.reduce.EventFetcher - EventFetcher is interrupted.. Returning
# 2023-01-27 00:12:35,386 [pool-4-thread-1] INFO  org.apache.hadoop.mapred.LocalJobRunner - 1 / 1 copied.
# 2023-01-27 00:12:35,386 [pool-4-thread-1] INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl - finalMerge called with 1 in-memory map-outputs and 0 on-disk map-outputs
# 2023-01-27 00:12:35,395 [pool-4-thread-1] INFO  org.apache.hadoop.mapred.Merger - Merging 1 sorted segments
# 2023-01-27 00:12:35,396 [pool-4-thread-1] INFO  org.apache.hadoop.mapred.Merger - Down to the last merge-pass, with 1 segments left of total size: 32808 bytes
# 2023-01-27 00:12:35,417 [pool-4-thread-1] INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl - Merged 1 segments, 32816 bytes to disk to satisfy reduce memory limit
# 2023-01-27 00:12:35,418 [pool-4-thread-1] INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl - Merging 1 files, 32820 bytes from disk
# 2023-01-27 00:12:35,419 [pool-4-thread-1] INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl - Merging 0 segments, 0 bytes from memory into reduce
# 2023-01-27 00:12:35,419 [pool-4-thread-1] INFO  org.apache.hadoop.mapred.Merger - Merging 1 sorted segments
# 2023-01-27 00:12:35,420 [pool-4-thread-1] INFO  org.apache.hadoop.mapred.Merger - Down to the last merge-pass, with 1 segments left of total size: 32808 bytes
# 2023-01-27 00:12:35,420 [pool-4-thread-1] INFO  org.apache.hadoop.mapred.LocalJobRunner - 1 / 1 copied.
# 2023-01-27 00:12:35,426 [pool-4-thread-1] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - File Output Committer Algorithm version is 2
# 2023-01-27 00:12:35,426 [pool-4-thread-1] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-01-27 00:12:35,429 [pool-4-thread-1] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.skip.on is deprecated. Instead, use mapreduce.job.skiprecords
# 2023-01-27 00:12:35,429 [pool-4-thread-1] INFO  org.apache.pig.impl.util.SpillableMemoryManager - Selected heap (G1 Old Gen) of size 1048576000 to monitor. collectionUsageThreshold = 734003200, usageThreshold = 734003200
# 2023-01-27 00:12:35,429 [pool-4-thread-1] WARN  org.apache.pig.data.SchemaTupleBackend - SchemaTupleBackend has already been initialized
# 2023-01-27 00:12:35,435 [pool-4-thread-1] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.PigMapReduce$Reduce - Aliases being processed per job phase (AliasName[line,offset]): M: ratings[2,10],ratings[-1,-1],avgRatings[10,13],groupedRating[8,16] C: avgRatings[10,13],groupedRating[8,16] R: avgRatings[10,13],badMovies[12,12]
# 2023-01-27 00:12:35,487 [pool-4-thread-1] INFO  org.apache.hadoop.mapred.Task - Task:attempt_local598888941_0001_r_000000_0 is done. And is in the process of committing
# 2023-01-27 00:12:35,492 [pool-4-thread-1] INFO  org.apache.hadoop.mapred.LocalJobRunner - 1 / 1 copied.
# 2023-01-27 00:12:35,493 [pool-4-thread-1] INFO  org.apache.hadoop.mapred.Task - Task attempt_local598888941_0001_r_000000_0 is allowed to commit now
# 2023-01-27 00:12:35,498 [pool-4-thread-1] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - Saved output of task 'attempt_local598888941_0001_r_000000_0' to file:/tmp/temp129970713/tmp-988448271
# 2023-01-27 00:12:35,499 [pool-4-thread-1] INFO  org.apache.hadoop.mapred.LocalJobRunner - reduce > reduce
# 2023-01-27 00:12:35,499 [pool-4-thread-1] INFO  org.apache.hadoop.mapred.Task - Task 'attempt_local598888941_0001_r_000000_0' done.
# 2023-01-27 00:12:35,500 [pool-4-thread-1] INFO  org.apache.hadoop.mapred.Task - Final Counters for attempt_local598888941_0001_r_000000_0: Counters: 24
# 	File System Counters
# 		FILE: Number of bytes read=2045266
# 		FILE: Number of bytes written=703076
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=1682
# 		Reduce shuffle bytes=32820
# 		Reduce input records=1682
# 		Reduce output records=129
# 		Spilled Records=1682
# 		Shuffled Maps =1
# 		Failed Shuffles=0
# 		Merged Map outputs=1
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=287309824
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Output Format Counters
# 		Bytes Written=0
# 2023-01-27 00:12:35,500 [pool-4-thread-1] INFO  org.apache.hadoop.mapred.LocalJobRunner - Finishing task: attempt_local598888941_0001_r_000000_0
# 2023-01-27 00:12:35,500 [Thread-5] INFO  org.apache.hadoop.mapred.LocalJobRunner - reduce task executor complete.
# 2023-01-27 00:12:35,691 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - 25% complete
# 2023-01-27 00:12:35,694 [main] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-27 00:12:35,708 [main] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-27 00:12:35,709 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.map.tasks is deprecated. Instead, use mapreduce.job.maps
# 2023-01-27 00:12:35,710 [main] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-27 00:12:35,744 [main] INFO  org.apache.pig.tools.pigstats.mapreduce.MRScriptState - Pig script settings are added to the job
# 2023-01-27 00:12:35,744 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler - mapred.job.reduce.markreset.buffer.percent is not set, set to default 0.3
# 2023-01-27 00:12:35,745 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler - Reduce phase detected, estimating # of required reducers.
# 2023-01-27 00:12:35,745 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler - Using reducer estimator: org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.InputSizeReducerEstimator
# 2023-01-27 00:12:35,747 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.InputSizeReducerEstimator - BytesPerReducer=1000000000 maxReducers=999 totalInputFileSize=238606
# 2023-01-27 00:12:35,747 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler - Setting Parallelism to 1
# 2023-01-27 00:12:35,749 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler - Setting up single store job
# 2023-01-27 00:12:35,773 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - 1 map-reduce job(s) waiting for submission.
# 2023-01-27 00:12:35,776 [JobControl] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-27 00:12:35,785 [JobControl] WARN  org.apache.hadoop.mapreduce.JobResourceUploader - No job jar file set.  User classes may not be found. See Job or Job#setJar(String).
# 2023-01-27 00:12:35,793 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2023-01-27 00:12:35,794 [JobControl] INFO  org.apache.pig.backend.hadoop.executionengine.util.MapRedUtil - Total input paths to process : 1
# 2023-01-27 00:12:35,794 [JobControl] INFO  org.apache.pig.backend.hadoop.executionengine.util.MapRedUtil - Total input paths (combined) to process : 1
# 2023-01-27 00:12:35,798 [JobControl] INFO  org.apache.pig.builtin.PigStorage - Using PigTextInputFormat
# 2023-01-27 00:12:35,803 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2023-01-27 00:12:35,803 [JobControl] INFO  org.apache.pig.backend.hadoop.executionengine.util.MapRedUtil - Total input paths to process : 1
# 2023-01-27 00:12:35,804 [JobControl] INFO  org.apache.pig.backend.hadoop.executionengine.util.MapRedUtil - Total input paths (combined) to process : 1
# 2023-01-27 00:12:35,809 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - number of splits:2
# 2023-01-27 00:12:35,826 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - Submitting tokens for job: job_local249840664_0002
# 2023-01-27 00:12:35,826 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - Executing with tokens: []
# 2023-01-27 00:12:35,917 [JobControl] INFO  org.apache.hadoop.mapreduce.Job - The url to track the job: http://localhost:8080/
# 2023-01-27 00:12:35,920 [Thread-14] INFO  org.apache.hadoop.mapred.LocalJobRunner - OutputCommitter set in config null
# 2023-01-27 00:12:35,929 [Thread-14] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.reduce.tasks is deprecated. Instead, use mapreduce.job.reduces
# 2023-01-27 00:12:35,929 [Thread-14] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.job.tracker is deprecated. Instead, use mapreduce.jobtracker.address
# 2023-01-27 00:12:35,929 [Thread-14] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.job.reduce.markreset.buffer.percent is deprecated. Instead, use mapreduce.reduce.markreset.buffer.percent
# 2023-01-27 00:12:35,929 [Thread-14] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - File Output Committer Algorithm version is 2
# 2023-01-27 00:12:35,929 [Thread-14] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-01-27 00:12:35,929 [Thread-14] INFO  org.apache.hadoop.mapred.LocalJobRunner - OutputCommitter is org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.PigOutputCommitter
# 2023-01-27 00:12:35,937 [Thread-14] INFO  org.apache.hadoop.mapred.LocalJobRunner - Waiting for map tasks
# 2023-01-27 00:12:35,938 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.LocalJobRunner - Starting task: attempt_local249840664_0002_m_000000_0
# 2023-01-27 00:12:35,953 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - File Output Committer Algorithm version is 2
# 2023-01-27 00:12:35,953 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-01-27 00:12:35,957 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.Task -  Using ResourceCalculatorProcessTree : [ ]
# 2023-01-27 00:12:35,959 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - Processing split: Number of splits :1
# Total Length = 236344
# Input split[0]:
#    Length = 236344
#    ClassName: org.apache.hadoop.mapreduce.lib.input.FileSplit
#    Locations:
#
# -----------------------
#
# 2023-01-27 00:12:35,963 [LocalJobRunner Map Task Executor #0] INFO  org.apache.pig.builtin.PigStorage - Using PigTextInputFormat
# 2023-01-27 00:12:35,963 [LocalJobRunner Map Task Executor #0] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.PigRecordReader - Current split being processed file:/content/data_pig/ml-100k/u.item:0+236344
# 2023-01-27 00:12:35,988 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - (EQUATOR) 0 kvi 26214396(104857584)
# 2023-01-27 00:12:36,001 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - mapreduce.task.io.sort.mb: 100
# 2023-01-27 00:12:36,001 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - soft limit at 83886080
# 2023-01-27 00:12:36,001 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - bufstart = 0; bufvoid = 104857600
# 2023-01-27 00:12:36,001 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - kvstart = 26214396; length = 6553600
# 2023-01-27 00:12:36,002 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2023-01-27 00:12:36,021 [LocalJobRunner Map Task Executor #0] INFO  org.apache.pig.impl.util.SpillableMemoryManager - Selected heap (G1 Old Gen) of size 1048576000 to monitor. collectionUsageThreshold = 734003200, usageThreshold = 734003200
# 2023-01-27 00:12:36,022 [LocalJobRunner Map Task Executor #0] WARN  org.apache.pig.data.SchemaTupleBackend - SchemaTupleBackend has already been initialized
# 2023-01-27 00:12:36,032 [LocalJobRunner Map Task Executor #0] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.PigGenericMapReduce$Map - Aliases being processed per job phase (AliasName[line,offset]): M: namedBadMovies[14,17],metadata[3,11],nameLookup[-1,-1],namedBadMovies[14,17] C:  R: results[16,10]
# 2023-01-27 00:12:36,099 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.LocalJobRunner -
# 2023-01-27 00:12:36,099 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - Starting flush of map output
# 2023-01-27 00:12:36,099 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - Spilling map output
# 2023-01-27 00:12:36,099 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - bufstart = 0; bufend = 59667; bufvoid = 104857600
# 2023-01-27 00:12:36,099 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - kvstart = 26214396(104857584); kvend = 26207672(104830688); length = 6725/6553600
# 2023-01-27 00:12:36,104 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - Finished spill 0
# 2023-01-27 00:12:36,114 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.Task - Task:attempt_local249840664_0002_m_000000_0 is done. And is in the process of committing
# 2023-01-27 00:12:36,122 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.LocalJobRunner - map
# 2023-01-27 00:12:36,122 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.Task - Task 'attempt_local249840664_0002_m_000000_0' done.
# 2023-01-27 00:12:36,123 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.Task - Final Counters for attempt_local249840664_0002_m_000000_0: Counters: 18
# 	File System Counters
# 		FILE: Number of bytes read=2282429
# 		FILE: Number of bytes written=1382702
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=1682
# 		Map output records=1682
# 		Map output bytes=59667
# 		Map output materialized bytes=63037
# 		Input split bytes=364
# 		Combine input records=0
# 		Spilled Records=1682
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=11
# 		Total committed heap usage (bytes)=287309824
# 	MultiInputCounters
# 		Input records from _1_u.item=1682
# 	File Input Format Counters
# 		Bytes Read=0
# 2023-01-27 00:12:36,123 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.LocalJobRunner - Finishing task: attempt_local249840664_0002_m_000000_0
# 2023-01-27 00:12:36,123 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.LocalJobRunner - Starting task: attempt_local249840664_0002_m_000001_0
# 2023-01-27 00:12:36,132 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - File Output Committer Algorithm version is 2
# 2023-01-27 00:12:36,132 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-01-27 00:12:36,133 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.Task -  Using ResourceCalculatorProcessTree : [ ]
# 2023-01-27 00:12:36,137 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - Processing split: Number of splits :1
# Total Length = 2262
# Input split[0]:
#    Length = 2262
#    ClassName: org.apache.hadoop.mapreduce.lib.input.FileSplit
#    Locations:
#
# -----------------------
#
# 2023-01-27 00:12:36,145 [LocalJobRunner Map Task Executor #0] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.PigRecordReader - Current split being processed file:/tmp/temp129970713/tmp-988448271/part-r-00000:0+2262
# 2023-01-27 00:12:36,192 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - (EQUATOR) 0 kvi 26214396(104857584)
# 2023-01-27 00:12:36,192 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - mapreduce.task.io.sort.mb: 100
# 2023-01-27 00:12:36,192 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - soft limit at 83886080
# 2023-01-27 00:12:36,192 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - bufstart = 0; bufvoid = 104857600
# 2023-01-27 00:12:36,192 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - kvstart = 26214396; length = 6553600
# 2023-01-27 00:12:36,193 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2023-01-27 00:12:36,198 [LocalJobRunner Map Task Executor #0] INFO  org.apache.pig.impl.util.SpillableMemoryManager - Selected heap (G1 Old Gen) of size 1048576000 to monitor. collectionUsageThreshold = 734003200, usageThreshold = 734003200
# 2023-01-27 00:12:36,199 [LocalJobRunner Map Task Executor #0] WARN  org.apache.pig.data.SchemaTupleBackend - SchemaTupleBackend has already been initialized
# 2023-01-27 00:12:36,207 [LocalJobRunner Map Task Executor #0] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.PigGenericMapReduce$Map - Aliases being processed per job phase (AliasName[line,offset]): M: namedBadMovies[14,17],metadata[3,11],nameLookup[-1,-1],namedBadMovies[14,17] C:  R: results[16,10]
# 2023-01-27 00:12:36,210 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.LocalJobRunner -
# 2023-01-27 00:12:36,210 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - Starting flush of map output
# 2023-01-27 00:12:36,210 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - Spilling map output
# 2023-01-27 00:12:36,210 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - bufstart = 0; bufend = 2522; bufvoid = 104857600
# 2023-01-27 00:12:36,210 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - kvstart = 26214396(104857584); kvend = 26213884(104855536); length = 513/6553600
# 2023-01-27 00:12:36,211 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - Finished spill 0
# 2023-01-27 00:12:36,224 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.Task - Task:attempt_local249840664_0002_m_000001_0 is done. And is in the process of committing
# 2023-01-27 00:12:36,229 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.LocalJobRunner - map
# 2023-01-27 00:12:36,229 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.Task - Task 'attempt_local249840664_0002_m_000001_0' done.
# 2023-01-27 00:12:36,229 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.Task - Final Counters for attempt_local249840664_0002_m_000001_0: Counters: 18
# 	File System Counters
# 		FILE: Number of bytes read=2285487
# 		FILE: Number of bytes written=1385520
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=129
# 		Map output records=129
# 		Map output bytes=2522
# 		Map output materialized bytes=2786
# 		Input split bytes=377
# 		Combine input records=0
# 		Spilled Records=129
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=23
# 		Total committed heap usage (bytes)=287309824
# 	MultiInputCounters
# 		Input records from _0_tmp-988448271=129
# 	File Input Format Counters
# 		Bytes Read=0
# 2023-01-27 00:12:36,230 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.LocalJobRunner - Finishing task: attempt_local249840664_0002_m_000001_0
# 2023-01-27 00:12:36,230 [Thread-14] INFO  org.apache.hadoop.mapred.LocalJobRunner - map task executor complete.
# 2023-01-27 00:12:36,236 [Thread-14] INFO  org.apache.hadoop.mapred.LocalJobRunner - Waiting for reduce tasks
# 2023-01-27 00:12:36,236 [pool-9-thread-1] INFO  org.apache.hadoop.mapred.LocalJobRunner - Starting task: attempt_local249840664_0002_r_000000_0
# 2023-01-27 00:12:36,277 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - HadoopJobId: job_local249840664_0002
# 2023-01-27 00:12:36,277 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - Processing aliases metadata,nameLookup,namedBadMovies,results
# 2023-01-27 00:12:36,277 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - detailed locations: M: namedBadMovies[14,17],metadata[3,11],nameLookup[-1,-1],namedBadMovies[14,17] C:  R: results[16,10]
# 2023-01-27 00:12:36,283 [pool-9-thread-1] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - File Output Committer Algorithm version is 2
# 2023-01-27 00:12:36,286 [pool-9-thread-1] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-01-27 00:12:36,286 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - 37% complete
# 2023-01-27 00:12:36,286 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - Running jobs are [job_local249840664_0002]
# 2023-01-27 00:12:36,290 [pool-9-thread-1] INFO  org.apache.hadoop.mapred.Task -  Using ResourceCalculatorProcessTree : [ ]
# 2023-01-27 00:12:36,290 [pool-9-thread-1] INFO  org.apache.hadoop.mapred.ReduceTask - Using ShuffleConsumerPlugin: org.apache.hadoop.mapreduce.task.reduce.Shuffle@26c0c2e7
# 2023-01-27 00:12:36,295 [pool-9-thread-1] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-27 00:12:36,297 [pool-9-thread-1] INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl - MergerManager: memoryLimit=734003200, maxSingleShuffleLimit=183500800, mergeThreshold=484442144, ioSortFactor=10, memToMemMergeOutputsThreshold=10
# 2023-01-27 00:12:36,305 [EventFetcher for fetching Map Completion Events] INFO  org.apache.hadoop.mapreduce.task.reduce.EventFetcher - attempt_local249840664_0002_r_000000_0 Thread started: EventFetcher for fetching Map Completion Events
# 2023-01-27 00:12:36,311 [localfetcher#2] INFO  org.apache.hadoop.mapreduce.task.reduce.LocalFetcher - localfetcher#2 about to shuffle output of map attempt_local249840664_0002_m_000000_0 decomp: 63033 len: 63037 to MEMORY
# 2023-01-27 00:12:36,316 [localfetcher#2] INFO  org.apache.hadoop.mapreduce.task.reduce.InMemoryMapOutput - Read 63033 bytes from map-output for attempt_local249840664_0002_m_000000_0
# 2023-01-27 00:12:36,317 [localfetcher#2] INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl - closeInMemoryFile -> map-output of size: 63033, inMemoryMapOutputs.size() -> 1, commitMemory -> 0, usedMemory ->63033
# 2023-01-27 00:12:36,318 [localfetcher#2] INFO  org.apache.hadoop.mapreduce.task.reduce.LocalFetcher - localfetcher#2 about to shuffle output of map attempt_local249840664_0002_m_000001_0 decomp: 2782 len: 2786 to MEMORY
# 2023-01-27 00:12:36,319 [localfetcher#2] INFO  org.apache.hadoop.mapreduce.task.reduce.InMemoryMapOutput - Read 2782 bytes from map-output for attempt_local249840664_0002_m_000001_0
# 2023-01-27 00:12:36,319 [localfetcher#2] INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl - closeInMemoryFile -> map-output of size: 2782, inMemoryMapOutputs.size() -> 2, commitMemory -> 63033, usedMemory ->65815
# 2023-01-27 00:12:36,319 [EventFetcher for fetching Map Completion Events] INFO  org.apache.hadoop.mapreduce.task.reduce.EventFetcher - EventFetcher is interrupted.. Returning
# 2023-01-27 00:12:36,320 [pool-9-thread-1] INFO  org.apache.hadoop.mapred.LocalJobRunner - 2 / 2 copied.
# 2023-01-27 00:12:36,320 [pool-9-thread-1] INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl - finalMerge called with 2 in-memory map-outputs and 0 on-disk map-outputs
# 2023-01-27 00:12:36,322 [pool-9-thread-1] INFO  org.apache.hadoop.mapred.Merger - Merging 2 sorted segments
# 2023-01-27 00:12:36,322 [pool-9-thread-1] INFO  org.apache.hadoop.mapred.Merger - Down to the last merge-pass, with 2 segments left of total size: 65799 bytes
# 2023-01-27 00:12:36,332 [pool-9-thread-1] INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl - Merged 2 segments, 65815 bytes to disk to satisfy reduce memory limit
# 2023-01-27 00:12:36,333 [pool-9-thread-1] INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl - Merging 1 files, 65817 bytes from disk
# 2023-01-27 00:12:36,333 [pool-9-thread-1] INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl - Merging 0 segments, 0 bytes from memory into reduce
# 2023-01-27 00:12:36,333 [pool-9-thread-1] INFO  org.apache.hadoop.mapred.Merger - Merging 1 sorted segments
# 2023-01-27 00:12:36,333 [pool-9-thread-1] INFO  org.apache.hadoop.mapred.Merger - Down to the last merge-pass, with 1 segments left of total size: 65805 bytes
# 2023-01-27 00:12:36,334 [pool-9-thread-1] INFO  org.apache.hadoop.mapred.LocalJobRunner - 2 / 2 copied.
# 2023-01-27 00:12:36,337 [pool-9-thread-1] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - File Output Committer Algorithm version is 2
# 2023-01-27 00:12:36,337 [pool-9-thread-1] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-01-27 00:12:36,349 [pool-9-thread-1] INFO  org.apache.pig.impl.util.SpillableMemoryManager - Selected heap (G1 Old Gen) of size 1048576000 to monitor. collectionUsageThreshold = 734003200, usageThreshold = 734003200
# 2023-01-27 00:12:36,349 [pool-9-thread-1] WARN  org.apache.pig.data.SchemaTupleBackend - SchemaTupleBackend has already been initialized
# 2023-01-27 00:12:36,352 [pool-9-thread-1] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.PigMapReduce$Reduce - Aliases being processed per job phase (AliasName[line,offset]): M: namedBadMovies[14,17],metadata[3,11],nameLookup[-1,-1],namedBadMovies[14,17] C:  R: results[16,10]
# 2023-01-27 00:12:36,379 [pool-9-thread-1] INFO  org.apache.hadoop.mapred.Task - Task:attempt_local249840664_0002_r_000000_0 is done. And is in the process of committing
# 2023-01-27 00:12:36,383 [pool-9-thread-1] INFO  org.apache.hadoop.mapred.LocalJobRunner - 2 / 2 copied.
# 2023-01-27 00:12:36,387 [pool-9-thread-1] INFO  org.apache.hadoop.mapred.Task - Task attempt_local249840664_0002_r_000000_0 is allowed to commit now
# 2023-01-27 00:12:36,399 [pool-9-thread-1] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - Saved output of task 'attempt_local249840664_0002_r_000000_0' to file:/tmp/temp129970713/tmp-109274888
# 2023-01-27 00:12:36,406 [pool-9-thread-1] INFO  org.apache.hadoop.mapred.LocalJobRunner - reduce > reduce
# 2023-01-27 00:12:36,406 [pool-9-thread-1] INFO  org.apache.hadoop.mapred.Task - Task 'attempt_local249840664_0002_r_000000_0' done.
# 2023-01-27 00:12:36,406 [pool-9-thread-1] INFO  org.apache.hadoop.mapred.Task - Final Counters for attempt_local249840664_0002_r_000000_0: Counters: 24
# 	File System Counters
# 		FILE: Number of bytes read=2417191
# 		FILE: Number of bytes written=1456893
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=1682
# 		Reduce shuffle bytes=65823
# 		Reduce input records=1811
# 		Reduce output records=129
# 		Spilled Records=1811
# 		Shuffled Maps =2
# 		Failed Shuffles=0
# 		Merged Map outputs=2
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=287309824
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Output Format Counters
# 		Bytes Written=0
# 2023-01-27 00:12:36,406 [pool-9-thread-1] INFO  org.apache.hadoop.mapred.LocalJobRunner - Finishing task: attempt_local249840664_0002_r_000000_0
# 2023-01-27 00:12:36,406 [Thread-14] INFO  org.apache.hadoop.mapred.LocalJobRunner - reduce task executor complete.
# 2023-01-27 00:12:36,522 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - 50% complete
# 2023-01-27 00:12:36,525 [main] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-27 00:12:36,536 [main] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-27 00:12:36,538 [main] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-27 00:12:36,554 [main] INFO  org.apache.pig.tools.pigstats.mapreduce.MRScriptState - Pig script settings are added to the job
# 2023-01-27 00:12:36,556 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler - mapred.job.reduce.markreset.buffer.percent is not set, set to default 0.3
# 2023-01-27 00:12:36,559 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler - Reduce phase detected, estimating # of required reducers.
# 2023-01-27 00:12:36,559 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler - Using reducer estimator: org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.InputSizeReducerEstimator
# 2023-01-27 00:12:36,568 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.InputSizeReducerEstimator - BytesPerReducer=1000000000 maxReducers=999 totalInputFileSize=5504
# 2023-01-27 00:12:36,572 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.JobControlCompiler - Setting Parallelism to 1
# ...
# Total Length = 5504
# Input split[0]:
#    Length = 5504
#    ClassName: org.apache.hadoop.mapreduce.lib.input.FileSplit
#    Locations:
#
# -----------------------
#
# 2023-01-27 00:12:37,776 [LocalJobRunner Map Task Executor #0] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.PigRecordReader - Current split being processed file:/tmp/temp129970713/tmp-109274888/part-r-00000:0+5504
# 2023-01-27 00:12:37,807 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - (EQUATOR) 0 kvi 26214396(104857584)
# 2023-01-27 00:12:37,809 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - mapreduce.task.io.sort.mb: 100
# 2023-01-27 00:12:37,813 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - soft limit at 83886080
# 2023-01-27 00:12:37,813 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - bufstart = 0; bufvoid = 104857600
# 2023-01-27 00:12:37,813 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - kvstart = 26214396; length = 6553600
# 2023-01-27 00:12:37,820 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 2023-01-27 00:12:37,822 [LocalJobRunner Map Task Executor #0] INFO  org.apache.pig.impl.util.SpillableMemoryManager - Selected heap (G1 Old Gen) of size 1048576000 to monitor. collectionUsageThreshold = 734003200, usageThreshold = 734003200
# 2023-01-27 00:12:37,822 [LocalJobRunner Map Task Executor #0] WARN  org.apache.pig.data.SchemaTupleBackend - SchemaTupleBackend has already been initialized
# 2023-01-27 00:12:37,823 [LocalJobRunner Map Task Executor #0] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.PigGenericMapReduce$Map - Aliases being processed per job phase (AliasName[line,offset]): M: finalResults[19,15] C:  R:
# 2023-01-27 00:12:37,843 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.LocalJobRunner -
# 2023-01-27 00:12:37,843 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - Starting flush of map output
# 2023-01-27 00:12:37,843 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - Spilling map output
# 2023-01-27 00:12:37,843 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - bufstart = 0; bufend = 6465; bufvoid = 104857600
# 2023-01-27 00:12:37,843 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - kvstart = 26214396(104857584); kvend = 26213884(104855536); length = 513/6553600
# 2023-01-27 00:12:37,845 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.MapTask - Finished spill 0
# 2023-01-27 00:12:37,852 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.Task - Task:attempt_local721441521_0004_m_000000_0 is done. And is in the process of committing
# 2023-01-27 00:12:37,853 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.LocalJobRunner - map
# 2023-01-27 00:12:37,853 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.Task - Task 'attempt_local721441521_0004_m_000000_0' done.
# 2023-01-27 00:12:37,853 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.Task - Final Counters for attempt_local721441521_0004_m_000000_0: Counters: 17
# 	File System Counters
# 		FILE: Number of bytes read=2432657
# 		FILE: Number of bytes written=2696597
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Map input records=129
# 		Map output records=129
# 		Map output bytes=6465
# 		Map output materialized bytes=6729
# 		Input split bytes=377
# 		Combine input records=0
# 		Spilled Records=129
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=21
# 		Total committed heap usage (bytes)=297795584
# 	File Input Format Counters
# 		Bytes Read=0
# 2023-01-27 00:12:37,853 [LocalJobRunner Map Task Executor #0] INFO  org.apache.hadoop.mapred.LocalJobRunner - Finishing task: attempt_local721441521_0004_m_000000_0
# 2023-01-27 00:12:37,853 [Thread-29] INFO  org.apache.hadoop.mapred.LocalJobRunner - map task executor complete.
# 2023-01-27 00:12:37,858 [Thread-29] INFO  org.apache.hadoop.mapred.LocalJobRunner - Waiting for reduce tasks
# 2023-01-27 00:12:37,862 [pool-15-thread-1] INFO  org.apache.hadoop.mapred.LocalJobRunner - Starting task: attempt_local721441521_0004_r_000000_0
# 2023-01-27 00:12:37,905 [pool-15-thread-1] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - File Output Committer Algorithm version is 2
# 2023-01-27 00:12:37,907 [pool-15-thread-1] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-01-27 00:12:37,910 [pool-15-thread-1] INFO  org.apache.hadoop.mapred.Task -  Using ResourceCalculatorProcessTree : [ ]
# 2023-01-27 00:12:37,917 [pool-15-thread-1] INFO  org.apache.hadoop.mapred.ReduceTask - Using ShuffleConsumerPlugin: org.apache.hadoop.mapreduce.task.reduce.Shuffle@4a43ef49
# 2023-01-27 00:12:37,917 [pool-15-thread-1] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-27 00:12:37,919 [pool-15-thread-1] INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl - MergerManager: memoryLimit=734003200, maxSingleShuffleLimit=183500800, mergeThreshold=484442144, ioSortFactor=10, memToMemMergeOutputsThreshold=10
# 2023-01-27 00:12:37,934 [EventFetcher for fetching Map Completion Events] INFO  org.apache.hadoop.mapreduce.task.reduce.EventFetcher - attempt_local721441521_0004_r_000000_0 Thread started: EventFetcher for fetching Map Completion Events
# 2023-01-27 00:12:37,937 [localfetcher#4] INFO  org.apache.hadoop.mapreduce.task.reduce.LocalFetcher - localfetcher#4 about to shuffle output of map attempt_local721441521_0004_m_000000_0 decomp: 6725 len: 6729 to MEMORY
# 2023-01-27 00:12:37,938 [localfetcher#4] INFO  org.apache.hadoop.mapreduce.task.reduce.InMemoryMapOutput - Read 6725 bytes from map-output for attempt_local721441521_0004_m_000000_0
# 2023-01-27 00:12:37,938 [localfetcher#4] INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl - closeInMemoryFile -> map-output of size: 6725, inMemoryMapOutputs.size() -> 1, commitMemory -> 0, usedMemory ->6725
# 2023-01-27 00:12:37,938 [EventFetcher for fetching Map Completion Events] INFO  org.apache.hadoop.mapreduce.task.reduce.EventFetcher - EventFetcher is interrupted.. Returning
# 2023-01-27 00:12:37,938 [pool-15-thread-1] INFO  org.apache.hadoop.mapred.LocalJobRunner - 1 / 1 copied.
# 2023-01-27 00:12:37,939 [pool-15-thread-1] INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl - finalMerge called with 1 in-memory map-outputs and 0 on-disk map-outputs
# 2023-01-27 00:12:37,940 [pool-15-thread-1] INFO  org.apache.hadoop.mapred.Merger - Merging 1 sorted segments
# 2023-01-27 00:12:37,940 [pool-15-thread-1] INFO  org.apache.hadoop.mapred.Merger - Down to the last merge-pass, with 1 segments left of total size: 6713 bytes
# 2023-01-27 00:12:37,941 [pool-15-thread-1] INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl - Merged 1 segments, 6725 bytes to disk to satisfy reduce memory limit
# 2023-01-27 00:12:37,941 [pool-15-thread-1] INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl - Merging 1 files, 6729 bytes from disk
# 2023-01-27 00:12:37,941 [pool-15-thread-1] INFO  org.apache.hadoop.mapreduce.task.reduce.MergeManagerImpl - Merging 0 segments, 0 bytes from memory into reduce
# 2023-01-27 00:12:37,941 [pool-15-thread-1] INFO  org.apache.hadoop.mapred.Merger - Merging 1 sorted segments
# 2023-01-27 00:12:37,941 [pool-15-thread-1] INFO  org.apache.hadoop.mapred.Merger - Down to the last merge-pass, with 1 segments left of total size: 6713 bytes
# 2023-01-27 00:12:37,942 [pool-15-thread-1] INFO  org.apache.hadoop.mapred.LocalJobRunner - 1 / 1 copied.
# 2023-01-27 00:12:37,945 [pool-15-thread-1] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - File Output Committer Algorithm version is 2
# 2023-01-27 00:12:37,945 [pool-15-thread-1] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 2023-01-27 00:12:37,947 [pool-15-thread-1] INFO  org.apache.pig.impl.util.SpillableMemoryManager - Selected heap (G1 Old Gen) of size 1048576000 to monitor. collectionUsageThreshold = 734003200, usageThreshold = 734003200
# 2023-01-27 00:12:37,947 [pool-15-thread-1] WARN  org.apache.pig.data.SchemaTupleBackend - SchemaTupleBackend has already been initialized
# 2023-01-27 00:12:37,950 [pool-15-thread-1] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.PigMapReduce$Reduce - Aliases being processed per job phase (AliasName[line,offset]): M: finalResults[19,15] C:  R:
# 2023-01-27 00:12:37,959 [pool-15-thread-1] INFO  org.apache.hadoop.mapred.Task - Task:attempt_local721441521_0004_r_000000_0 is done. And is in the process of committing
# 2023-01-27 00:12:37,965 [pool-15-thread-1] INFO  org.apache.hadoop.mapred.LocalJobRunner - 1 / 1 copied.
# 2023-01-27 00:12:37,966 [pool-15-thread-1] INFO  org.apache.hadoop.mapred.Task - Task attempt_local721441521_0004_r_000000_0 is allowed to commit now
# 2023-01-27 00:12:37,978 [pool-15-thread-1] INFO  org.apache.hadoop.mapreduce.lib.output.FileOutputCommitter - Saved output of task 'attempt_local721441521_0004_r_000000_0' to file:/tmp/temp129970713/tmp2130548758
# 2023-01-27 00:12:37,979 [pool-15-thread-1] INFO  org.apache.hadoop.mapred.LocalJobRunner - reduce > reduce
# 2023-01-27 00:12:37,979 [pool-15-thread-1] INFO  org.apache.hadoop.mapred.Task - Task 'attempt_local721441521_0004_r_000000_0' done.
# 2023-01-27 00:12:37,980 [pool-15-thread-1] INFO  org.apache.hadoop.mapred.Task - Final Counters for attempt_local721441521_0004_r_000000_0: Counters: 24
# 	File System Counters
# 		FILE: Number of bytes read=2446147
# 		FILE: Number of bytes written=2708882
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 	Map-Reduce Framework
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=25
# 		Reduce shuffle bytes=6729
# 		Reduce input records=129
# 		Reduce output records=129
# 		Spilled Records=129
# 		Shuffled Maps =1
# 		Failed Shuffles=0
# 		Merged Map outputs=1
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=297795584
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Output Format Counters
# 		Bytes Written=0
# 2023-01-27 00:12:37,980 [pool-15-thread-1] INFO  org.apache.hadoop.mapred.LocalJobRunner - Finishing task: attempt_local721441521_0004_r_000000_0
# 2023-01-27 00:12:37,980 [Thread-29] INFO  org.apache.hadoop.mapred.LocalJobRunner - reduce task executor complete.
# 2023-01-27 00:12:37,985 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - HadoopJobId: job_local721441521_0004
# 2023-01-27 00:12:37,985 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - Processing aliases finalResults
# 2023-01-27 00:12:37,985 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - detailed locations: M: finalResults[19,15] C:  R:
# 2023-01-27 00:12:38,006 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - Running jobs are [job_local721441521_0004]
# 2023-01-27 00:12:38,132 [main] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-27 00:12:38,134 [main] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-27 00:12:38,135 [main] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-27 00:12:38,150 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - 100% complete
# 2023-01-27 00:12:38,161 [main] INFO  org.apache.pig.tools.pigstats.mapreduce.SimplePigStats - Script Statistics:
#
# HadoopVersion	PigVersion	UserId	StartedAt	FinishedAt	Features
# 3.3.4	0.17.0	root	2023-01-27 00:12:32	2023-01-27 00:12:38	HASH_JOIN,GROUP_BY,ORDER_BY,FILTER
#
# Success!
#
# Job Stats (time in seconds):
# JobId	Maps	Reduces	MaxMapTime	MinMapTime	AvgMapTime	MedianMapTime	MaxReduceTime	MinReduceTime	AvgReduceTime	MedianReducetime	Alias	Feature	Outputs
# job_local207039519_0003	1	1	n/a	n/a	n/a	n/a	n/a	n/a	n/a	n/a	finalResults	SAMPLER
# job_local249840664_0002	2	1	n/a	n/a	n/a	n/a	n/a	n/a	n/a	n/a	metadata,nameLookup,namedBadMovies,results	HASH_JOIN
# job_local598888941_0001	1	1	n/a	n/a	n/a	n/a	n/a	n/a	n/a	n/a	avgRatings,badMovies,groupedRating,ratings	GROUP_BY,COMBINER
# job_local721441521_0004	1	1	n/a	n/a	n/a	n/a	n/a	n/a	n/a	n/a	finalResults	ORDER_BY	file:/tmp/temp129970713/tmp2130548758,
#
# Input(s):
# Successfully read 100000 records from: "file:///content/data_pig/ml-100k/u.data"
# Successfully read 1682 records from: "file:///content/data_pig/ml-100k/u.item"
#
# Output(s):
# Successfully stored 129 records in: "file:/tmp/temp129970713/tmp2130548758"
#
# Counters:
# Total records written : 129
# Total bytes written : 0
# Spillable Memory Manager spill count : 0
# Total bags proactively spilled: 0
# Total records proactively spilled: 0
#
# Job DAG:
# job_local598888941_0001	->	job_local249840664_0002,
# job_local249840664_0002	->	job_local207039519_0003,
# job_local207039519_0003	->	job_local721441521_0004,
# job_local721441521_0004
#
#
# 2023-01-27 00:12:38,162 [main] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-27 00:12:38,165 [main] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-27 00:12:38,166 [main] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-27 00:12:38,175 [main] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-27 00:12:38,177 [main] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-27 00:12:38,178 [main] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-27 00:12:38,183 [main] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-27 00:12:38,185 [main] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-27 00:12:38,186 [main] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-27 00:12:38,190 [main] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-27 00:12:38,192 [main] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-27 00:12:38,193 [main] WARN  org.apache.hadoop.metrics2.impl.MetricsSystemImpl - JobTracker metrics system already initialized!
# 2023-01-27 00:12:38,200 [main] INFO  org.apache.pig.backend.hadoop.executionengine.mapReduceLayer.MapReduceLauncher - Success!
# 2023-01-27 00:12:38,204 [main] WARN  org.apache.pig.data.SchemaTupleBackend - SchemaTupleBackend has already been initialized
# 2023-01-27 00:12:38,206 [main] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2023-01-27 00:12:38,206 [main] INFO  org.apache.pig.backend.hadoop.executionengine.util.MapRedUtil - Total input paths to process : 1
# 2023-01-27 00:12:38,251 [main] INFO  org.apache.pig.Main - Pig script completed in 7 seconds and 404 milliseconds (7404 ms)

# %% [markdown]
# In the file we will see all rows order by timestamp and rating.

# %%
# !head BadPopularMovies.txt
# Out:
# (Leave It to Beaver (1997),1.8409090909090908,44)
# (Mortal Kombat: Annihilation (1997),1.9534883720930232,43)
# (Crow: City of Angels, The (1996),1.9487179487179487,39)
# (Bio-Dome (1996),1.903225806451613,31)
# (Barb Wire (1996),1.9333333333333333,30)
# (Free Willy 3: The Rescue (1997),1.7407407407407407,27)
# (Showgirls (1995),1.9565217391304348,23)
# (Lawnmower Man 2: Beyond Cyberspace (1996),1.7142857142857142,21)
# (Children of the Corn: The Gathering (1996),1.3157894736842106,19)
# (Home Alone 3 (1997),1.894736842105263,19)

# %% [markdown]
# ---
#
# ### 9th - Say thanks, give like and share if this has been of help/interest 😁🖖
#
# ---
